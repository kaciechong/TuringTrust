# %%
# !pip install "pymongo[srv]"
import pymongo
from pymongo import MongoClient
import pandas as pd
# Out:
# Requirement already satisfied: pymongo[srv] in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (4.10.1)
# WARNING: pymongo 4.10.1 does not provide the extra 'srv'
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pymongo[srv]) (2.7.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Database access credentials: to establish a connection to the MongoDB server using the MongoClient.
# The connection string includes the username (user), password(123), and database details.
client = MongoClient("mongodb+srv://user:123@cluster0.9d0ja.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")

# Access the 'blancco' database
db = client["blancco"]

# Access the 'all_reports' collection within the 'blancco' database
all_reports_collection = db["all_reports"]

# Can now use 'all_reports_collection' to perform operations like find, insert, update, or aggregate data

# %%
pipeline = [
    # Unwind to process each erasure and disk entry separately
    { "$unwind": "$disks" },
    { "$unwind": "$erasures" },
    
    # Match on SATA/SSD interface type and successful erasure state
    {
        "$match": {
            "disks.interface_type": "SATA/SSD",
            "erasures.interface_type": "SATA/SSD",
            "erasures.state": "Successful"
        }
    },

    # Project required fields, including converted capacity, elapsed time, and erasure rate
    {
        "$project": {
            "_id": 0,
            "interface_type": "$erasures.interface_type",
            "model": "$erasures.model",
            "serial_number": "$erasures.serial",
            "capacity_gb": { "$divide": ["$erasures.capacity", 1073741824] },  # Convert bytes to GB
            "elapsed_time_seconds": {
                "$add": [
                    { "$multiply": [{ "$toInt": { "$arrayElemAt": [{ "$split": ["$erasures.elapsed_time", ":"] }, 0] } }, 3600] },
                    { "$multiply": [{ "$toInt": { "$arrayElemAt": [{ "$split": ["$erasures.elapsed_time", ":"] }, 1] } }, 60] },
                    { "$toInt": { "$arrayElemAt": [{ "$split": ["$erasures.elapsed_time", ":"] }, 2] } }
                ]
            }
        }
    },

    # Calculate erasure rate in GB/min and handle zero-division cases
    {
        "$project": {
            "interface_type": 1,
            "model": 1,
            "serial_number": 1,
            "capacity_gb": 1,
            "elapsed_time_minutes": { "$divide": ["$elapsed_time_seconds", 60] },
            "erasure_rate_gb_per_min": {
                "$cond": {
                    "if": { "$gt": ["$elapsed_time_seconds", 0] },  # Ensure elapsed time is > 0
                    "then": { "$divide": ["$capacity_gb", { "$divide": ["$elapsed_time_seconds", 60] }] },
                    "else": None  # Set to null if elapsed time is zero
                }
            }
        }
    },

    # Sort results by serial number for clarity and analysis
    { "$sort": { "serial_number": 1, "erasure_rate_gb_per_min": 1 } }
]

# %%
results = list(all_reports_collection.aggregate(pipeline))

# Output results
for result in results:
    print(result)
# Out:
# {'interface_type': 'SATA/SSD', 'model': 'SSD', 'serial_number': '00000000012022910093', 'capacity_gb': 29.818199157714844, 'elapsed_time_minutes': 59.833333333333336, 'erasure_rate_gb_per_min': 0.49835430347155724}
# {'interface_type': 'SATA/SSD', 'model': 'SSD', 'serial_number': '0000000001202291010D', 'capacity_gb': 29.818199157714844, 'elapsed_time_minutes': 63.06666666666667, 'erasure_rate_gb_per_min': 0.4728044263908273}
# {'interface_type': 'SATA/SSD', 'model': 'C300-CTFDDAC128MAG', 'serial_number': '00000000100500006F68', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.6, 'erasure_rate_gb_per_min': 3.171343499041618}
# {'interface_type': 'SATA/SSD', 'model': 'C300-CTFDDAC064MAG', 'serial_number': '00000000104502FEF229', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 33.21666666666667, 'erasure_rate_gb_per_min': 1.7950718904103815}
# {'interface_type': 'SATA/SSD', 'model': 'C300-CTFDDAC064MAG', 'serial_number': '00000000104502FEF229', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 33.21666666666667, 'erasure_rate_gb_per_min': 1.7950718904103815}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDBAK128MAG-1G1', 'serial_number': '00000000110208009E3E', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 234.21666666666667, 'erasure_rate_gb_per_min': 0.5091119998461461}
# {'interface_type': 'SATA/SSD', 'model': 'C300-CTFDDAC064MAG', 'serial_number': '0000000011190307778A', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 36.06666666666667, 'erasure_rate_gb_per_min': 1.6532247123788772}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT064M4SSD2', 'serial_number': '0000000011250312A090', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 77.4, 'erasure_rate_gb_per_min': 0.770365692848383}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDBAK128MAG-1G1', 'serial_number': '00000000112603130C41', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 198.15, 'erasure_rate_gb_per_min': 0.6017790338832442}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDBAK128MAG-1G1', 'serial_number': '0000000011290314A1D7', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 306.4, 'erasure_rate_gb_per_min': 0.38917270092677825}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDBAK128MAG-1G1', 'serial_number': '0000000011290314C659', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 231.93333333333334, 'erasure_rate_gb_per_min': 0.5141240969989861}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDBAK128MAG-1G1', 'serial_number': '0000000011320316C9A1', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 186.23333333333332, 'erasure_rate_gb_per_min': 0.6402855677320468}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDBAK128MAG-1G1', 'serial_number': '0000000011320316C9A1', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 41.55, 'erasure_rate_gb_per_min': 2.869855970251862}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT128M4SSD2', 'serial_number': '0000000011330318214B', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 28.983333333333334, 'erasure_rate_gb_per_min': 4.114175350108045}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT512M4SSD1', 'serial_number': '000000001202032A158A', 'capacity_gb': 476.93978118896484, 'elapsed_time_minutes': 88.43333333333334, 'erasure_rate_gb_per_min': 5.393212753738766}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT512M4SSD1', 'serial_number': '000000001202032A158A', 'capacity_gb': 476.93978118896484, 'elapsed_time_minutes': 84.65, 'erasure_rate_gb_per_min': 5.634256127453807}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT256M4SSD2', 'serial_number': '00000000120509044B35', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 78.71666666666667, 'erasure_rate_gb_per_min': 3.029535516904063}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT064M4SSD2', 'serial_number': '0000000012060904F012', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 22.966666666666665, 'erasure_rate_gb_per_min': 2.5962106513700225}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT128M4SSD2', 'serial_number': '0000000012180909A539', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 47.13333333333333, 'erasure_rate_gb_per_min': 2.5298977842425354}
# {'interface_type': 'SATA/SSD', 'model': 'C400-MTFDDAK064MAM', 'serial_number': '00000000121909217FD9', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 25.716666666666665, 'erasure_rate_gb_per_min': 2.318586051579968}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT064M4SSD2', 'serial_number': '0000000012350914D4B0', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 25.5, 'erasure_rate_gb_per_min': 2.338286455939798}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT064M4SSD2', 'serial_number': '0000000012350914D4B1', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 22.816666666666666, 'erasure_rate_gb_per_min': 2.613278508099263}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT064M4SSD2', 'serial_number': '0000000012350914D4B9', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 24.116666666666667, 'erasure_rate_gb_per_min': 2.4724106963288808}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT064M4SSD2', 'serial_number': '0000000012350914D511', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 29.366666666666667, 'erasure_rate_gb_per_min': 2.030407649028315}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT064M4SSD2', 'serial_number': '0000000012350914D513', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 28.833333333333332, 'erasure_rate_gb_per_min': 2.0679643223051394}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT064M4SSD2', 'serial_number': '0000000012350914D51B', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 27.55, 'erasure_rate_gb_per_min': 2.1642941788190506}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT064M4SSD2', 'serial_number': '0000000012350914D51D', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 28.85, 'erasure_rate_gb_per_min': 2.0667696577630794}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT064M4SSD2', 'serial_number': '0000000012350914D545', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 24.75, 'erasure_rate_gb_per_min': 2.4091436212713067}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT064M4SSD2', 'serial_number': '0000000012350914D7E4', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 24.516666666666666, 'erasure_rate_gb_per_min': 2.432072248530177}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT064M4SSD2', 'serial_number': '0000000012350914D7E7', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 12.066666666666666, 'erasure_rate_gb_per_min': 4.941406460756755}
# {'interface_type': 'SATA/SSD', 'model': 'C400-MTFDDAK128MAM', 'serial_number': '0000000012470355E2BB', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 36.75, 'erasure_rate_gb_per_min': 3.244694301060268}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT128M4SSD2', 'serial_number': '000000001248091E7E4B', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 40.15, 'erasure_rate_gb_per_min': 2.9699256678447035}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT128M4SSD2', 'serial_number': '00000000125109213C4B', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 35.15, 'erasure_rate_gb_per_min': 3.392390200966283}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT128M4SSD2', 'serial_number': '00000000125109213C50', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 39.11666666666667, 'erasure_rate_gb_per_min': 3.048381309688066}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT128M4SSD2', 'serial_number': '0000000012510921939C', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 32.15, 'erasure_rate_gb_per_min': 3.708942941336387}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT128M4SSD2', 'serial_number': '00000000130409275040', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 28.383333333333333, 'erasure_rate_gb_per_min': 4.201145586516671}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT128M4SSD2', 'serial_number': '00000000130409277B87', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 14.666666666666666, 'erasure_rate_gb_per_min': 8.130171515724877}
# {'interface_type': 'SATA/SSD', 'model': 'M4-CT256M4SSD2', 'serial_number': '0000000013040927E607', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 57.2, 'erasure_rate_gb_per_min': 4.169142262918966}
# {'interface_type': 'SATA/SSD', 'model': 'C400-MTFDDAC064MAM', 'serial_number': '000000001349095CA69A', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 24.15, 'erasure_rate_gb_per_min': 2.4689981211786685}
# {'interface_type': 'SATA/SSD', 'model': 'C400-MTFDDAC064MAM', 'serial_number': '000000001349095CA6D4', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 24.8, 'erasure_rate_gb_per_min': 2.4042864768735823}
# {'interface_type': 'SATA/SSD', 'model': 'C400-MTFDDAC064MAM', 'serial_number': '000000001349095CA6E3', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 24.033333333333335, 'erasure_rate_gb_per_min': 2.48098354895138}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': '002007101H42', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 41.11666666666667, 'erasure_rate_gb_per_min': 2.9001017277860237}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': '002007101H4T', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 40.96666666666667, 'erasure_rate_gb_per_min': 2.9107204891977703}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': '002007101H5F', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 49.71666666666667, 'erasure_rate_gb_per_min': 2.3984414892551524}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-64L6G-HP', 'serial_number': '002338127844', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 42.31666666666667, 'erasure_rate_gb_per_min': 1.4090501290224067}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-64L6G-HP', 'serial_number': '002338127844', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 23.783333333333335, 'erasure_rate_gb_per_min': 2.5070625631309675}
# {'interface_type': 'SATA/SSD', 'model': 'LMS-32L6M-HP', 'serial_number': '002339105187', 'capacity_gb': 29.818199157714844, 'elapsed_time_minutes': 16.633333333333333, 'erasure_rate_gb_per_min': 1.7926773040710327}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-64L6G-HP', 'serial_number': '002342136577', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 22.916666666666668, 'erasure_rate_gb_per_min': 2.6018751109730114}
# {'interface_type': 'SATA/SSD', 'model': 'LMS-32L6M-HP', 'serial_number': '002402121303', 'capacity_gb': 29.818199157714844, 'elapsed_time_minutes': 33.06666666666667, 'erasure_rate_gb_per_min': 0.9017600551728279}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443136277', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 84.3, 'erasure_rate_gb_per_min': 1.4145019639853482}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443136421', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 20.433333333333334, 'erasure_rate_gb_per_min': 5.835685916670384}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443136426', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 73.45, 'erasure_rate_gb_per_min': 1.6234515393324007}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443136439', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 21.2, 'erasure_rate_gb_per_min': 5.624646960564379}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443136441', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 20.483333333333334, 'erasure_rate_gb_per_min': 5.821440955116265}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443136480', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 114.05, 'erasure_rate_gb_per_min': 1.0455284135376137}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443136658', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 64.3, 'erasure_rate_gb_per_min': 1.8544714706681935}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443136659', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 8.3, 'erasure_rate_gb_per_min': 14.366568140236726}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443136671', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 20.283333333333335, 'erasure_rate_gb_per_min': 5.878842180639187}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443136673', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 20.6, 'erasure_rate_gb_per_min': 5.788471629318681}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443136679', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 85.5, 'erasure_rate_gb_per_min': 1.3946493048416941}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443136686', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 26.016666666666666, 'erasure_rate_gb_per_min': 4.583312577730871}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443136697', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 20.616666666666667, 'erasure_rate_gb_per_min': 5.78379218580266}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443136699', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 80.15, 'erasure_rate_gb_per_min': 1.4877419284337472}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443137042', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 66.48333333333333, 'erasure_rate_gb_per_min': 1.7935700510999977}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443137045', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 76.88333333333334, 'erasure_rate_gb_per_min': 1.5509540285796424}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443137066', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 20.516666666666666, 'erasure_rate_gb_per_min': 5.8119828869519825}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443137207', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 106.41666666666667, 'erasure_rate_gb_per_min': 1.120524813443679}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443137215', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 21.05, 'erasure_rate_gb_per_min': 5.664727580235859}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443137221', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 20.65, 'erasure_rate_gb_per_min': 5.774455959514037}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443137228', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 20.716666666666665, 'erasure_rate_gb_per_min': 5.75587363945124}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443137843', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 22.5, 'erasure_rate_gb_per_min': 5.2996673583984375}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443137852', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 19.883333333333333, 'erasure_rate_gb_per_min': 5.997108913527151}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443137874', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 21.05, 'erasure_rate_gb_per_min': 5.664727580235859}
# {'interface_type': 'SATA/SSD', 'model': 'L8T-128L6G-HP', 'serial_number': '002443137890', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 89.13333333333334, 'erasure_rate_gb_per_min': 1.3377993518769429}
# {'interface_type': 'SATA/SSD', 'model': 'IT LCS-128L9S-HP', 'serial_number': '002510117711', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 24.016666666666666, 'erasure_rate_gb_per_min': 4.9649902386106115}
# {'interface_type': 'SATA/SSD', 'model': 'IT L8T-128L9G-HP', 'serial_number': '002524109230', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 143.75, 'erasure_rate_gb_per_min': 0.8295131517493206}
# {'interface_type': 'SATA/SSD', 'model': 'IT L8T-128L9G-HP', 'serial_number': '002532163924', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 42.583333333333336, 'erasure_rate_gb_per_min': 2.8002156296821488}
# {'interface_type': 'SATA/SSD', 'model': 'IT L8T-128L9G-HP', 'serial_number': '002532163927', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 22.366666666666667, 'erasure_rate_gb_per_min': 5.331260010311394}
# {'interface_type': 'SATA/SSD', 'model': 'IT L8T-128L9G-HP', 'serial_number': '002532163931', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 74.2, 'erasure_rate_gb_per_min': 1.6070419887326797}
# {'interface_type': 'SATA/SSD', 'model': 'IT L8T-128L9G-HP', 'serial_number': '002532163942', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 75.21666666666667, 'erasure_rate_gb_per_min': 1.585320393050718}
# {'interface_type': 'SATA/SSD', 'model': 'IT L8T-128L9G-HP', 'serial_number': '002532163947', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 9.1, 'erasure_rate_gb_per_min': 13.103573138897236}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-128V2G-HP', 'serial_number': '002536114199', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 35.583333333333336, 'erasure_rate_gb_per_min': 3.3510777207671616}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-128V2G-HP', 'serial_number': '002536114208', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 36.36666666666667, 'erasure_rate_gb_per_min': 3.2788959366809762}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-128V2G-HP', 'serial_number': '002536114225', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 35.68333333333333, 'erasure_rate_gb_per_min': 3.3416865641466096}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-128V2G-HP', 'serial_number': '002536114263', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 36.56666666666667, 'erasure_rate_gb_per_min': 3.2609621393973973}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-128V2G-HP', 'serial_number': '002536117137', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 36.2, 'erasure_rate_gb_per_min': 3.2939921426509624}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-128V2G-HP', 'serial_number': '002536117137', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 36.15, 'erasure_rate_gb_per_min': 3.29854814838077}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-128V2G-HP', 'serial_number': '002536117138', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 36.46666666666667, 'erasure_rate_gb_per_min': 3.2699044487376097}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-128V2G-HP', 'serial_number': '002536117145', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 36.85, 'erasure_rate_gb_per_min': 3.2358891604875124}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-128V2G-HP', 'serial_number': '002536117145', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 36.61666666666667, 'erasure_rate_gb_per_min': 3.256509300791029}
# {'interface_type': 'SATA/SSD', 'model': 'LCH-256V2S-HP', 'serial_number': '0025471017A2', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 41.21666666666667, 'erasure_rate_gb_per_min': 5.785886068070315}
# {'interface_type': 'SATA/SSD', 'model': 'LCH-256V2S-HP', 'serial_number': '0025471017CV', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 41.68333333333333, 'erasure_rate_gb_per_min': 5.7211100545133515}
# {'interface_type': 'SATA/SSD', 'model': 'CV1-8B256-HP', 'serial_number': '002611101108', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 36.86666666666667, 'erasure_rate_gb_per_min': 6.468578773208812}
# {'interface_type': 'SATA/SSD', 'model': 'LCH-256V2S-HP', 'serial_number': '002611102LK1', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 41.15, 'erasure_rate_gb_per_min': 5.795259719051394}
# {'interface_type': 'SATA/SSD', 'model': 'CV1-8B128', 'serial_number': '002615100KMH', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 31.766666666666666, 'erasure_rate_gb_per_min': 3.7536993356966897}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-128V2G-HP', 'serial_number': '00261910289F', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 36.55, 'erasure_rate_gb_per_min': 3.2624491262370685}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '0026221018FR', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 42.833333333333336, 'erasure_rate_gb_per_min': 5.567508267057545}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '0026221018GK', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 43.1, 'erasure_rate_gb_per_min': 5.533061193479463}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '0026221019VK', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 44.78333333333333, 'erasure_rate_gb_per_min': 5.325082339537734}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '0026251013LW', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 43.88333333333333, 'erasure_rate_gb_per_min': 5.434294054818796}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '002626100JBQ', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 43.083333333333336, 'erasure_rate_gb_per_min': 5.535201642683903}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '002626101AS9', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 42.583333333333336, 'erasure_rate_gb_per_min': 5.60019422557256}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '002626101ASK', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 43.333333333333336, 'erasure_rate_gb_per_min': 5.503267787053034}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '002626101ASP', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 43.016666666666666, 'erasure_rate_gb_per_min': 5.543780025702398}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '002626101RK3', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 42.85, 'erasure_rate_gb_per_min': 5.565342764036519}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '002626101RKF', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 42.46666666666667, 'erasure_rate_gb_per_min': 5.615579374543913}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '002627101QX6', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 43.7, 'erasure_rate_gb_per_min': 5.457092389907662}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '002628100969', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 43.1, 'erasure_rate_gb_per_min': 5.533061193479463}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-128V2G-HP', 'serial_number': '002630101C6H', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 42.86666666666667, 'erasure_rate_gb_per_min': 2.7817072060022903}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-128V2G-HP', 'serial_number': '002630101C6J', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.36666666666667, 'erasure_rate_gb_per_min': 3.107971734942611}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-128V2G-HP', 'serial_number': '002630101C6K', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 36.516666666666666, 'erasure_rate_gb_per_min': 3.2654271719935606}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-128V2G-HP', 'serial_number': '002630101C6M', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 35.85, 'erasure_rate_gb_per_min': 3.3261510617563412}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '002632101841', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 43.35, 'erasure_rate_gb_per_min': 5.501151959376352}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '002632101841', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 43.1, 'erasure_rate_gb_per_min': 5.533061193479463}
# {'interface_type': 'SATA/SSD', 'model': 'CV1-8B256-HP', 'serial_number': '002634100KR6', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 38.2, 'erasure_rate_gb_per_min': 6.242799409396985}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '002637101MAS', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 44.21666666666667, 'erasure_rate_gb_per_min': 5.393326892701806}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '0026381008C5', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 45.083333333333336, 'erasure_rate_gb_per_min': 5.2896474108458005}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '002640101A3H', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 42.516666666666666, 'erasure_rate_gb_per_min': 5.608975400367656}
# {'interface_type': 'SATA/SSD', 'model': 'L8H-256V2G-HP', 'serial_number': '002644101BTP', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 45.733333333333334, 'erasure_rate_gb_per_min': 5.214466562076491}
# {'interface_type': 'SATA/SSD', 'model': 'CV1-8B256-HP', 'serial_number': '002646100EA0', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 37.05, 'erasure_rate_gb_per_min': 6.436570511173141}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE256-HP', 'serial_number': '0027201011VT', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 49.583333333333336, 'erasure_rate_gb_per_min': 4.80957857019761}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE256-HP', 'serial_number': '0027201011VV', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 50.05, 'erasure_rate_gb_per_min': 4.7647340147645325}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE256-HP', 'serial_number': '0027201011VX', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 51.833333333333336, 'erasure_rate_gb_per_min': 4.6008026515555915}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '0027301000PH', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 94.13333333333334, 'erasure_rate_gb_per_min': 1.2667406044330543}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '0027301000Q3', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 89.91666666666667, 'erasure_rate_gb_per_min': 1.326144751406467}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '0027301000Q7', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.11666666666667, 'erasure_rate_gb_per_min': 3.2126407426303953}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '0027301000QN', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 36.9, 'erasure_rate_gb_per_min': 3.2315044868283156}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '0027301000QP', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.71666666666667, 'erasure_rate_gb_per_min': 3.1615337754475874}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '0027301001XE', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.1, 'erasure_rate_gb_per_min': 3.2140839774653593}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '0027301001XK', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.3, 'erasure_rate_gb_per_min': 3.113381607414226}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '0027301001XL', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 91.06666666666666, 'erasure_rate_gb_per_min': 1.3093980479205511}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '0027301001XM', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.43333333333333, 'erasure_rate_gb_per_min': 3.1854634611922936}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '0027301001XT', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.78333333333333, 'erasure_rate_gb_per_min': 3.1559554185434013}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '0027301001XW', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.6, 'erasure_rate_gb_per_min': 3.171343499041618}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '0027301002B1', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.016666666666666, 'erasure_rate_gb_per_min': 3.1365852406128414}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '002738100RVF', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 36.78333333333333, 'erasure_rate_gb_per_min': 3.2417539346796063}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '002738100RVK', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.78333333333333, 'erasure_rate_gb_per_min': 3.1559554185434013}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '002738100RVM', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 212.03333333333333, 'erasure_rate_gb_per_min': 0.5623762721142817}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '002738100RVN', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.03333333333333, 'erasure_rate_gb_per_min': 3.2198699072177726}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '002738100RW6', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.96666666666667, 'erasure_rate_gb_per_min': 3.06011588273648}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '002738100RWT', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 39.083333333333336, 'erasure_rate_gb_per_min': 3.0509812084596546}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '002738100RWT', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.8, 'erasure_rate_gb_per_min': 3.154563903808594}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '002738100RWU', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 51.86666666666667, 'erasure_rate_gb_per_min': 2.2990202229556203}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '002738100UQR', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.65, 'erasure_rate_gb_per_min': 3.167131887489106}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '002738100UQS', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.45, 'erasure_rate_gb_per_min': 3.1840458094516646}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '002738100UQU', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 41.2, 'erasure_rate_gb_per_min': 2.8942358146593405}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '002738100UQW', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.6, 'erasure_rate_gb_per_min': 3.0891843410353585}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE128-HP', 'serial_number': '002738100UR8', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 36.983333333333334, 'erasure_rate_gb_per_min': 3.224223043640329}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100LKW', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.21666666666667, 'erasure_rate_gb_per_min': 3.1201704901168297}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100M8F', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.833333333333336, 'erasure_rate_gb_per_min': 3.1517845523514936}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100M8H', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.13333333333333, 'erasure_rate_gb_per_min': 3.211198803338371}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100M8U', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.45, 'erasure_rate_gb_per_min': 3.1012357753957045}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100M9D', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.733333333333334, 'erasure_rate_gb_per_min': 3.1601373382676194}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100M9F', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.81666666666667, 'erasure_rate_gb_per_min': 3.1531736156182855}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100M9G', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.78333333333333, 'erasure_rate_gb_per_min': 3.074581406892089}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100M9V', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.75, 'erasure_rate_gb_per_min': 3.158742134144764}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MA1', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.15, 'erasure_rate_gb_per_min': 3.1256229505626436}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MA2', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.86666666666667, 'erasure_rate_gb_per_min': 3.1490100941187897}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MA3', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.5, 'erasure_rate_gb_per_min': 3.097208196466619}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MA6', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.43333333333333, 'erasure_rate_gb_per_min': 3.1854634611922936}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MAK', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.3, 'erasure_rate_gb_per_min': 3.196850283216216}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MAP', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.21666666666667, 'erasure_rate_gb_per_min': 3.1201704901168297}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MG3', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.46666666666667, 'erasure_rate_gb_per_min': 3.182629418967033}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MG9', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.666666666666664, 'erasure_rate_gb_per_min': 3.165730501698182}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MGA', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.916666666666664, 'erasure_rate_gb_per_min': 3.1448575533353367}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MGD', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.63333333333333, 'erasure_rate_gb_per_min': 3.16853451454291}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MGJ', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.28333333333333, 'erasure_rate_gb_per_min': 3.1147370195201964}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MGN', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.45, 'erasure_rate_gb_per_min': 3.1012357753957045}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MGP', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 64.2, 'erasure_rate_gb_per_min': 1.857360055513471}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MGQ', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.1, 'erasure_rate_gb_per_min': 3.2140839774653593}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MGU', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.28333333333333, 'erasure_rate_gb_per_min': 3.1982793624666477}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MGW', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.93333333333333, 'erasure_rate_gb_per_min': 3.143475805728423}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MH4', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.38333333333333, 'erasure_rate_gb_per_min': 3.10662220314281}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MH6', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.1, 'erasure_rate_gb_per_min': 3.129724817951833}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MHJ', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.733333333333334, 'erasure_rate_gb_per_min': 3.1601373382676194}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MHW', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.86666666666667, 'erasure_rate_gb_per_min': 3.1490100941187897}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MHX', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.81666666666667, 'erasure_rate_gb_per_min': 3.1531736156182855}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100MJ5', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 16.766666666666666, 'erasure_rate_gb_per_min': 7.111879655902476}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N1E', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 36.86666666666667, 'erasure_rate_gb_per_min': 3.2344262811202036}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N1R', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.55, 'erasure_rate_gb_per_min': 3.175566326603591}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N1V', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.03333333333333, 'erasure_rate_gb_per_min': 3.135210751024492}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N1X', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.21666666666667, 'erasure_rate_gb_per_min': 3.1201704901168297}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N20', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.53333333333333, 'erasure_rate_gb_per_min': 3.176976435984854}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N21', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.8, 'erasure_rate_gb_per_min': 3.154563903808594}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N23', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.13333333333333, 'erasure_rate_gb_per_min': 3.211198803338371}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N24', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.8, 'erasure_rate_gb_per_min': 3.154563903808594}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N2H', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 16.666666666666668, 'erasure_rate_gb_per_min': 7.15455093383789}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N2L', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.45, 'erasure_rate_gb_per_min': 3.1012357753957045}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N2N', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.31666666666667, 'erasure_rate_gb_per_min': 3.1120273744401437}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N2P', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.46666666666667, 'erasure_rate_gb_per_min': 3.182629418967033}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N33', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.38333333333333, 'erasure_rate_gb_per_min': 3.10662220314281}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N36', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.45, 'erasure_rate_gb_per_min': 3.1840458094516646}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N3A', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.96666666666667, 'erasure_rate_gb_per_min': 3.140715949884939}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002747100N3D', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.6, 'erasure_rate_gb_per_min': 3.171343499041618}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '0027521000E1', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.96666666666667, 'erasure_rate_gb_per_min': 3.140715949884939}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '0027521000EU', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.766666666666666, 'erasure_rate_gb_per_min': 3.1573481614465537}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE256-HP', 'serial_number': '002752100DVQ', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 46.35, 'erasure_rate_gb_per_min': 5.145090343882736}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE256-HP', 'serial_number': '00281610292F', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 50.28333333333333, 'erasure_rate_gb_per_min': 4.742623880125254}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-CE256-HP', 'serial_number': '0028161029JQ', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 50.31666666666667, 'erasure_rate_gb_per_min': 4.739482029260646}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '00282610050C', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 63.9, 'erasure_rate_gb_per_min': 1.8660800557740977}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '00282610050E', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.95, 'erasure_rate_gb_per_min': 3.1420952717777295}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '00282610050U', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.666666666666664, 'erasure_rate_gb_per_min': 3.165730501698182}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '002826100510', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.53333333333333, 'erasure_rate_gb_per_min': 3.176976435984854}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '00282610051F', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.36666666666667, 'erasure_rate_gb_per_min': 3.107971734942611}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '00282610051K', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.56666666666667, 'erasure_rate_gb_per_min': 3.1741574684285228}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '00282610051L', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.11666666666667, 'erasure_rate_gb_per_min': 3.128356333116699}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '00282610051N', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 64.21666666666667, 'erasure_rate_gb_per_min': 1.8568779999579264}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '00282610051Q', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 38.53333333333333, 'erasure_rate_gb_per_min': 3.094528950621925}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '00282610051U', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 37.5, 'erasure_rate_gb_per_min': 3.1798004150390624}
# {'interface_type': 'SATA/SSD', 'model': 'CV3-8D128-HP', 'serial_number': '00282610051X', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 39.266666666666666, 'erasure_rate_gb_per_min': 3.0367363895746564}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': '002902101B1S', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 39.833333333333336, 'erasure_rate_gb_per_min': 2.9935359675515145}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': '002911100E2N', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 37.733333333333334, 'erasure_rate_gb_per_min': 3.1601373509046464}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': '002911100E2N', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 16.25, 'erasure_rate_gb_per_min': 7.338000987126277}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': '002943101387', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 45.68333333333333, 'erasure_rate_gb_per_min': 2.6101973595213868}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': '0029431016JF', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 39.13333333333333, 'erasure_rate_gb_per_min': 3.0470830334106136}
# {'interface_type': 'SATA/SSD', 'model': 'TS120GSSD220S', 'serial_number': '0102421BD52370790644', 'capacity_gb': 111.79048919677734, 'elapsed_time_minutes': 97.11666666666666, 'erasure_rate_gb_per_min': 1.1510947917979477}
# {'interface_type': 'SATA/SSD', 'model': 'KingFast', 'serial_number': '02152220S0054', 'capacity_gb': 476.93978118896484, 'elapsed_time_minutes': 628.85, 'erasure_rate_gb_per_min': 0.7584317105652617}
# {'interface_type': 'SATA/SSD', 'model': 'KingFast', 'serial_number': '02152220T0264', 'capacity_gb': 476.93978118896484, 'elapsed_time_minutes': 409.98333333333335, 'erasure_rate_gb_per_min': 1.163315048227078}
# {'interface_type': 'SATA/SSD', 'model': 'KingFast', 'serial_number': '02152220T0266', 'capacity_gb': 476.93978118896484, 'elapsed_time_minutes': 410.56666666666666, 'erasure_rate_gb_per_min': 1.1616622096020903}
# {'interface_type': 'SATA/SSD', 'model': 'SSD S510 120GB', 'serial_number': '02724111501000000017', 'capacity_gb': 111.79048919677734, 'elapsed_time_minutes': 58.93333333333333, 'erasure_rate_gb_per_min': 1.8968974411217876}
# {'interface_type': 'SATA/SSD', 'model': 'SSD S510 120GB', 'serial_number': '02724111501000000017', 'capacity_gb': 111.79048919677734, 'elapsed_time_minutes': 58.93333333333333, 'erasure_rate_gb_per_min': 1.8968974411217876}
# {'interface_type': 'SATA/SSD', 'model': 'SSD S510 120GB', 'serial_number': '02724111501000000033', 'capacity_gb': 111.79048919677734, 'elapsed_time_minutes': 59.05, 'erasure_rate_gb_per_min': 1.8931496900385665}
# {'interface_type': 'SATA/SSD', 'model': 'SSD S510 120GB', 'serial_number': '02724111501000000033', 'capacity_gb': 111.79048919677734, 'elapsed_time_minutes': 59.05, 'erasure_rate_gb_per_min': 1.8931496900385665}
# {'interface_type': 'SATA/SSD', 'model': 'KingFast', 'serial_number': '03022220C0319', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 710.5666666666667, 'erasure_rate_gb_per_min': 0.33561233396673756}
# {'interface_type': 'SATA/SSD', 'model': 'SP900', 'serial_number': '03220185500200001011', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 45.53333333333333, 'erasure_rate_gb_per_min': 2.6187960958411023}
# {'interface_type': 'SATA/SSD', 'model': '512G SSD', 'serial_number': '03252221Q0251', 'capacity_gb': 476.93978118896484, 'elapsed_time_minutes': 302.98333333333335, 'erasure_rate_gb_per_min': 1.5741452704405021}
# ...
# {'interface_type': 'SATA/SSD', 'model': 'LMT-256M6M mSATA 256GB', 'serial_number': 'TW0XXM305508542I4653', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 40.35, 'erasure_rate_gb_per_min': 5.910159539999128}
# {'interface_type': 'SATA/SSD', 'model': 'LJT-128L6G-11 M.2 2260 128GB', 'serial_number': 'TW0Y48CM550854722931', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 29.35, 'erasure_rate_gb_per_min': 4.062777361634236}
# {'interface_type': 'SATA/SSD', 'model': 'LJT-128L6G-11 M.2 2260 128GB', 'serial_number': 'TW0Y48CM550854722935', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 18.683333333333334, 'erasure_rate_gb_per_min': 6.382293428936566}
# {'interface_type': 'SATA/SSD', 'model': 'LJT-128L6G-11 M.2 2260 128GB', 'serial_number': 'TW0Y48CM550854CI0358', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 8.233333333333333, 'erasure_rate_gb_per_min': 14.482896627202209}
# {'interface_type': 'SATA/SSD', 'model': 'LJT-128L6G-11 M.2 2260 128GB', 'serial_number': 'TW0Y48CM5508551J0940', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 33.55, 'erasure_rate_gb_per_min': 3.5541733402075963}
# {'interface_type': 'SATA/SSD', 'model': 'X1 SSD', 'serial_number': 'TW1812501366', 'capacity_gb': 223.57088470458984, 'elapsed_time_minutes': 38.31666666666667, 'erasure_rate_gb_per_min': 5.834820827436011}
# {'interface_type': 'SATA/SSD', 'model': 'X1 SSD', 'serial_number': 'TW1812503486', 'capacity_gb': 223.57088470458984, 'elapsed_time_minutes': 37.166666666666664, 'erasure_rate_gb_per_min': 6.015360126580893}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDDAK256TBN-1AR1ZABHA', 'serial_number': 'UFZMN01J773SHW', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 89.68333333333334, 'erasure_rate_gb_per_min': 2.6590775406686284}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDDAK256TBN-1AR1ZABHA', 'serial_number': 'UFZMN01J7A19Y0', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 66.7, 'erasure_rate_gb_per_min': 3.5753363933877784}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDDAV256TBN-1AR15ABHA', 'serial_number': 'UFZNP01ZRADBUK', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 63.15, 'erasure_rate_gb_per_min': 3.7763252167690395}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDDAK512TBN-1AR1ZABHA', 'serial_number': 'UGXVL01D1BD5VN', 'capacity_gb': 476.93978118896484, 'elapsed_time_minutes': 35.233333333333334, 'erasure_rate_gb_per_min': 13.536606845476769}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDDAK512TBN-1AR1ZABHA', 'serial_number': 'UGXVL01J1BEJYJ', 'capacity_gb': 476.93978118896484, 'elapsed_time_minutes': 88.8, 'erasure_rate_gb_per_min': 5.370943481857712}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDDAV256TBN-1AR1ZABHA', 'serial_number': 'UGXVP01J7AZMY8', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 68.83333333333333, 'erasure_rate_gb_per_min': 3.4645269361592956}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDDAV256TBN-1AR1ZABHA', 'serial_number': 'UGXVP01J7AZS4U', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 68.15, 'erasure_rate_gb_per_min': 3.4992654062944215}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDDAV256TBN-1AR1ZABHA', 'serial_number': 'UGXVP01N4BHCCQ', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 73.71666666666667, 'erasure_rate_gb_per_min': 3.2350206299656095}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDDAV256TBN-1AR1ZABHA', 'serial_number': 'UGXVP01N4BHCRO', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 86.75, 'erasure_rate_gb_per_min': 2.7489906333021885}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDDAV256TBN-1AR1ZABHA', 'serial_number': 'UGXVP01N4BHQF6', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 74.91666666666667, 'erasure_rate_gb_per_min': 3.1832027244355707}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDDAV256TBN-1AR1ZABHA', 'serial_number': 'UGXVP01ZRBFFRV', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 84.98333333333333, 'erasure_rate_gb_per_min': 2.806137722364756}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDDAV256TBN-1AR1ZABHA', 'serial_number': 'UGXVP01ZRBQPQP', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 67.51666666666667, 'erasure_rate_gb_per_min': 3.5320899151661047}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDDAV256TBN-1AR15ABHA', 'serial_number': 'UGXVR01ZRBKOZR', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 69.56666666666666, 'erasure_rate_gb_per_min': 3.4280058088974346}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDDAK256TBN-1AR15ABHA', 'serial_number': 'UGXWQ01J7B02A2', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 64.9, 'erasure_rate_gb_per_min': 3.674498265623495}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': 'UHANC01ZTDX8N4', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 16.3, 'erasure_rate_gb_per_min': 7.315491781644294}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': 'UHANC01ZTDX8N6', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 35.96666666666667, 'erasure_rate_gb_per_min': 3.3153618917739203}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': 'UHANC01ZTDX8NB', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 35.516666666666666, 'erasure_rate_gb_per_min': 3.3573678847715254}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': 'UHANC01ZTDX8NF', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 35.93333333333333, 'erasure_rate_gb_per_min': 3.318437366627143}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': 'UHANC01ZTE55VS', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 35.733333333333334, 'erasure_rate_gb_per_min': 3.3370107100970707}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': 'UHANC01ZTE55W1', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 36.03333333333333, 'erasure_rate_gb_per_min': 3.309228012233173}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': 'UHANC01ZTE55W3', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 35.93333333333333, 'erasure_rate_gb_per_min': 3.318437366627143}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': 'UHANC01ZTE55W4', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 36.15, 'erasure_rate_gb_per_min': 3.2985481615712864}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': 'UHANC01ZTE55W5', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 35.88333333333333, 'erasure_rate_gb_per_min': 3.3230612923586254}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': 'UHANC01ZTE55W6', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 36.2, 'erasure_rate_gb_per_min': 3.2939921558232594}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': 'UHANC01ZTE55WC', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 35.86666666666667, 'erasure_rate_gb_per_min': 3.3246054658216173}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': 'UHANC01ZTE55WE', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 35.6, 'erasure_rate_gb_per_min': 3.349508877550618}
# {'interface_type': 'SATA/SSD', 'model': 'CV8-8E128-HP', 'serial_number': 'UHANC01ZTE55WF', 'capacity_gb': 119.242516040802, 'elapsed_time_minutes': 36.03333333333333, 'erasure_rate_gb_per_min': 3.309228012233173}
# {'interface_type': 'SATA/SSD', 'model': 'MTFDDAV256TDL-1AW1ZABHA', 'serial_number': 'UHZKQ0153DABIO', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 52.516666666666666, 'erasure_rate_gb_per_min': 4.540938193061851}
# {'interface_type': 'SATA/SSD', 'model': 'V7 S6000250G', 'serial_number': 'VM4549812D017C06842', 'capacity_gb': 232.88591766357422, 'elapsed_time_minutes': 46.05, 'erasure_rate_gb_per_min': 5.057240340142763}
# {'interface_type': 'SATA/SSD', 'model': 'THNSNJ128GMCT', 'serial_number': 'X3ES10CUTW7Y', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 32.28333333333333, 'erasure_rate_gb_per_min': 3.6936246431790867}
# {'interface_type': 'SATA/SSD', 'model': 'THNSNK256GVN8 M.2 2280 256GB', 'serial_number': 'X77S12B9TXUT', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 65.46666666666667, 'erasure_rate_gb_per_min': 3.6426925270717643}
# {'interface_type': 'SATA/SSD', 'model': 'THNSNK256GVN8 M.2 2280 256GB', 'serial_number': 'X77S12BKTXUT', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 86.28333333333333, 'erasure_rate_gb_per_min': 2.7638586529530405}
# {'interface_type': 'SATA/SSD', 'model': 'TOSHIBA-TR200', 'serial_number': 'X8MB7304K4FP', 'capacity_gb': 447.13167572021484, 'elapsed_time_minutes': 134.53333333333333, 'erasure_rate_gb_per_min': 3.323575389397038}
# {'interface_type': 'SATA/SSD', 'model': 'KSG60ZMV256G M.2 2280 256GB', 'serial_number': 'X8UB54JNK5RP', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 44.7, 'erasure_rate_gb_per_min': 5.335009786106596}
# {'interface_type': 'SATA/SSD', 'model': 'KSG60ZMV256G M.2 2280 256GB', 'serial_number': 'X8UB552OK5RP', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 83.55, 'erasure_rate_gb_per_min': 2.854278126139615}
# {'interface_type': 'SATA/SSD', 'model': 'KSG60ZMV256G M.2 2280 256GB', 'serial_number': 'X8UB55A2K5RP', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 54.0, 'erasure_rate_gb_per_min': 4.416202545166016}
# {'interface_type': 'SATA/SSD', 'model': 'KSG60ZMV256G M.2 2280 256GB', 'serial_number': 'X8UB55BVK5RP', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 43.65, 'erasure_rate_gb_per_min': 5.463343354844556}
# {'interface_type': 'SATA/SSD', 'model': 'KSG60ZMV256G M.2 2280 256GB', 'serial_number': 'X8UB55FRK5RP', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 58.21666666666667, 'erasure_rate_gb_per_min': 4.0963344535751185}
# {'interface_type': 'SATA/SSD', 'model': 'VERTEX PLUS', 'serial_number': 'Y1IIWG0XRJX43Y4FD771', 'capacity_gb': 55.900291442871094, 'elapsed_time_minutes': 38.06666666666667, 'erasure_rate_gb_per_min': 1.4684840133854051}
# {'interface_type': 'SATA/SSD', 'model': 'THNSNX032GTNT', 'serial_number': 'Y33B305VK5AX', 'capacity_gb': 29.818199157714844, 'elapsed_time_minutes': 46.45, 'erasure_rate_gb_per_min': 0.6419418548485434}
# {'interface_type': 'SATA/SSD', 'model': 'THNSNJ128GCSU', 'serial_number': 'Y4RS11F9T8MW', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 125.85, 'erasure_rate_gb_per_min': 0.9474971439329746}
# {'interface_type': 'SATA/SSD', 'model': 'THNSNK128GVN8 M.2 2280 128GB', 'serial_number': 'Y6ES10MAT1ZT', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 39.03333333333333, 'erasure_rate_gb_per_min': 3.0548893825097743}
# {'interface_type': 'SATA/SSD', 'model': 'KSG60ZMV256G M.2 2280 256GB', 'serial_number': 'Y79F22V9FPBS', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 43.833333333333336, 'erasure_rate_gb_per_min': 5.440492869329996}
# {'interface_type': 'SATA/SSD', 'model': 'KSG60ZMV256G M.2 2280 256GB', 'serial_number': 'Y79F22VEFPBS', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 46.03333333333333, 'erasure_rate_gb_per_min': 5.180483796646594}
# {'interface_type': 'SATA/SSD', 'model': 'KSG60ZMV256G M.2 2280 256GB', 'serial_number': 'Y7AB71G0KP6S', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 81.9, 'erasure_rate_gb_per_min': 2.9117818979116583}
# {'interface_type': 'SATA/SSD', 'model': 'KSG60ZMV256G M.2 2280 256GB', 'serial_number': 'Y7AB71Z9KP6S', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 46.53333333333333, 'erasure_rate_gb_per_min': 5.124819572470591}
# {'interface_type': 'SATA/SSD', 'model': 'KSG60ZMV256G M.2 2280 256GB', 'serial_number': 'Y7AB72X9KP6S', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 39.3, 'erasure_rate_gb_per_min': 6.068064565876968}
# {'interface_type': 'SATA/SSD', 'model': 'SSD PM800 TH 64GB', 'serial_number': 'YF1E801005SY005C1578', 'capacity_gb': 59.626304626464844, 'elapsed_time_minutes': 38.06666666666667, 'erasure_rate_gb_per_min': 1.5663652703975002}
# {'interface_type': 'SATA/SSD', 'model': 'SH00R240GB', 'serial_number': 'YR902079Q0392', 'capacity_gb': 223.57088470458984, 'elapsed_time_minutes': 146.53333333333333, 'erasure_rate_gb_per_min': 1.525733972051341}
# {'interface_type': 'SATA/SSD', 'model': 'SH00R240GB', 'serial_number': 'YR902079Q0509', 'capacity_gb': 223.57088470458984, 'elapsed_time_minutes': 143.05, 'erasure_rate_gb_per_min': 1.5628862964319457}
# {'interface_type': 'SATA/SSD', 'model': 'SH00R240GB', 'serial_number': 'YR903081Q0036', 'capacity_gb': 223.57088470458984, 'elapsed_time_minutes': 638.5, 'erasure_rate_gb_per_min': 0.35015017181611563}
# {'interface_type': 'SATA/SSD', 'model': 'SH00R240GB', 'serial_number': 'YR927069Q0359', 'capacity_gb': 223.57088470458984, 'elapsed_time_minutes': 143.33333333333334, 'erasure_rate_gb_per_min': 1.5597968700320222}
# {'interface_type': 'SATA/SSD', 'model': 'SH00R240GB', 'serial_number': 'YR927069Q0374', 'capacity_gb': 223.57088470458984, 'elapsed_time_minutes': 103.45, 'erasure_rate_gb_per_min': 2.1611491996577077}
# {'interface_type': 'SATA/SSD', 'model': '2-Power SSD2042B 256GB', 'serial_number': 'YS202010000247419', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 338.31666666666666, 'erasure_rate_gb_per_min': 0.704886755324789}
# {'interface_type': 'SATA/SSD', 'model': 'SSD TS064C', 'serial_number': 'Z1OA529NK6HK', 'capacity_gb': 56.5, 'elapsed_time_minutes': 7.433333333333334, 'erasure_rate_gb_per_min': 7.600896860986547}
# {'interface_type': 'SATA/SSD', 'model': 'Q300.', 'serial_number': 'Z5MB362AK1KU', 'capacity_gb': 111.79048919677734, 'elapsed_time_minutes': 31.316666666666666, 'erasure_rate_gb_per_min': 3.5696803362462166}
# {'interface_type': 'SATA/SSD', 'model': 'Q300.', 'serial_number': 'Z5NB313XK1KU', 'capacity_gb': 111.79048919677734, 'elapsed_time_minutes': 70.31666666666666, 'erasure_rate_gb_per_min': 1.5898149684301117}
# {'interface_type': 'SATA/SSD', 'model': 'Q300.', 'serial_number': 'Z5NB34OWK1KU', 'capacity_gb': 111.79048919677734, 'elapsed_time_minutes': 63.8, 'erasure_rate_gb_per_min': 1.752202025027858}
# {'interface_type': 'SATA/SSD', 'model': 'Q300.', 'serial_number': 'Z5OB31FIK1KU', 'capacity_gb': 111.79048919677734, 'elapsed_time_minutes': 64.51666666666667, 'erasure_rate_gb_per_min': 1.7327381430655233}
# {'interface_type': 'SATA/SSD', 'model': 'Q300.', 'serial_number': 'Z5OB31N1K1KU', 'capacity_gb': 111.79048919677734, 'elapsed_time_minutes': 43.21666666666667, 'erasure_rate_gb_per_min': 2.586744832937385}
# {'interface_type': 'SATA/SSD', 'model': 'THNSNJ256G8NY', 'serial_number': 'Z5RS10C8TG1V', 'capacity_gb': 238.47493743896484, 'elapsed_time_minutes': 94.56666666666666, 'erasure_rate_gb_per_min': 2.5217652883922965}
# {'interface_type': 'SATA/SSD', 'model': 'THNSNK128GVN8 M.2 2280 128GB', 'serial_number': 'Z64B313FKLNU', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 40.733333333333334, 'erasure_rate_gb_per_min': 2.9273939991153397}
# {'interface_type': 'SATA/SSD', 'model': 'THNSNK128GVN8 M.2 2280 128GB', 'serial_number': 'Z64S11BZT20T', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 39.43333333333333, 'erasure_rate_gb_per_min': 3.02390149359167}
# {'interface_type': 'SATA/SSD', 'model': 'THNSNK128GVN8 M.2 2280 128GB', 'serial_number': 'Z64S11CST20T', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 40.31666666666667, 'erasure_rate_gb_per_min': 2.9576481743852376}
# {'interface_type': 'SATA/SSD', 'model': 'THNSNK128GVN8 M.2 2280 128GB', 'serial_number': 'Z64S11OET20T', 'capacity_gb': 119.24251556396484, 'elapsed_time_minutes': 41.93333333333333, 'erasure_rate_gb_per_min': 2.843621197868796}
# {'interface_type': 'SATA/SSD', 'model': 'A100', 'serial_number': 'Z6DB60OAKQ8U', 'capacity_gb': 223.57088470458984, 'elapsed_time_minutes': 95.43333333333334, 'erasure_rate_gb_per_min': 2.342691771267096}
