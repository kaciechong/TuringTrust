# %%
# !pip install "pymongo[srv]"
import pymongo
from pymongo import MongoClient
import pandas as pd
# Out:
# Requirement already satisfied: pymongo[srv] in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (4.10.1)
# WARNING: pymongo 4.10.1 does not provide the extra 'srv'
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pymongo[srv]) (2.7.0)

# %%
# Database access credentials: to establish a connection to the MongoDB server using the MongoClient.
# The connection string includes the username (user), password(123), and database details.
client = MongoClient("mongodb+srv://user:123@cluster0.9d0ja.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")

# Access the 'blancco' database
db = client["blancco"]

# Access the 'all_reports' collection within the 'blancco' database
all_reports_collection = db["all_reports"]

# Can now use 'all_reports_collection' to perform operations like find, insert, update, or aggregate data

# %%
pipeline = [
    # Unwind the disks array to create a document for each disk
    { "$unwind": "$disks" },
    
    # Unwind the erasures array to create a document for each erasure
    { "$unwind": "$erasures" },

    # Match documents where the disks have a non-null interface type 
    # and the erasure state is "Successful"
    {
        "$match": {
            "disks.interface_type": { "$ne": None },  # Check for non-null interface_type
            "erasures.state": "Successful"              # Check for successful erasure state
        }
    },
    
    # Project the fields we are interested in for the next stage
    {
        "$project": {
            "interface_type": "$disks.interface_type",
            "model": "$disks.model",
            "serial_number": "$disks.serial",
            "raw_capacity": "$disks.capacity",  # Keep the raw capacity for debugging
            "capacity_gb": { "$divide": ["$disks.capacity", 1073741824] },  # Convert bytes to GB
            "raw_elapsed_time": "$erasures.elapsed_time",  # Keep raw elapsed time for debugging
            "elapsed_time_seconds": {
                "$add": [
                    { 
                        "$multiply": [
                            { 
                                "$toInt": { 
                                    "$arrayElemAt": [ 
                                        { "$split": ["$erasures.elapsed_time", ":"] }, 0 
                                    ] 
                                } 
                            },
                            3600  # Convert hours to seconds
                        ]
                    },
                    { 
                        "$multiply": [
                            { 
                                "$toInt": { 
                                    "$arrayElemAt": [ 
                                        { "$split": ["$erasures.elapsed_time", ":"] }, 1 
                                    ] 
                                } 
                            },
                            60  # Convert minutes to seconds
                        ]
                    },
                    { 
                        "$toInt": { 
                            "$arrayElemAt": [ 
                                { "$split": ["$erasures.elapsed_time", ":"] }, 2 
                            ] 
                        } 
                    }  # Get seconds
                ]
            }
        }
    },
    
    # Filter to only include documents with positive raw capacity and elapsed time
    {
        "$match": {
            "raw_capacity": { "$gt": 0 },  # Keep documents where raw_capacity is greater than 0
            "elapsed_time_seconds": { "$gt": 0 }  # Ensure elapsed time is greater than 0
        }
    },
    
    # Final projection of the necessary fields for output
    {
        "$project": {
            "interface_type": 1,
            "model": 1,
            "serial_number": 1,
            "raw_capacity": 1,  # Include raw capacity for comparison
            "capacity_gb": 1,  # Include capacity_gb in the final output
            "raw_elapsed_time": 1,  # Include raw elapsed time for debugging
            "elapsed_time_seconds": 1,  # Ensure this is included for distinct records
            
            # Calculate the erasure rate in GB per minute
            "erasure_rate": {
                "$cond": {
                    "if": { "$gt": ["$elapsed_time_seconds", 0] },
                    "then": {
                        "$divide": [
                            "$capacity_gb",  # Use capacity_gb directly
                            { "$divide": ["$elapsed_time_seconds", 60] }  # Convert elapsed time to minutes
                        ]
                    },
                    "else": None
                }
            }
        }
    },
    
    # Sort the results by interface type and serial number for clarity
    {
        "$sort": { "interface_type": 1, "serial_number": 1 }
    }
]

# Run the pipeline
results = all_reports_collection.aggregate(pipeline)
list(results)
# Out:
# [{'_id': ObjectId('66e8140c8bad1c495d53b79a'),
#   'interface_type': 'EMMC',
#   'model': 'MMC64G',
#   'serial_number': '0x00022c02',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:01',
#   'elapsed_time_seconds': 301,
#   'erasure_rate': 11.609738372093023},
#  {'_id': ObjectId('66e8140c8bad1c495d53eb17'),
#   'interface_type': 'EMMC',
#   'model': 'HAG2e',
#   'serial_number': '0x011f6a02',
#   'raw_capacity': 15762194432,
#   'capacity_gb': 14.6796875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 2.9359375},
#  {'_id': ObjectId('66e8140c8bad1c495d53b9e9'),
#   'interface_type': 'EMMC',
#   'model': 'HAG2e',
#   'serial_number': '0x0532893e',
#   'raw_capacity': 15762194432,
#   'capacity_gb': 14.6796875,
#   'raw_elapsed_time': '00:05:09',
#   'elapsed_time_seconds': 309,
#   'erasure_rate': 2.8504247572815533},
#  {'_id': ObjectId('66e8140c8bad1c495d53cde6'),
#   'interface_type': 'EMMC',
#   'model': 'SEM16G',
#   'serial_number': '0x0544b0ad',
#   'raw_capacity': 15758000128,
#   'capacity_gb': 14.67578125,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 2.93515625},
#  {'_id': ObjectId('66e8140c8bad1c495d53e6e5'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x10992841',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53e261'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x19f7c40f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53dffa'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x1c0cc50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53d967'),
#   'interface_type': 'EMMC',
#   'model': 'SEM16G',
#   'serial_number': '0x205e6880',
#   'raw_capacity': 15758000128,
#   'capacity_gb': 14.67578125,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 2.93515625},
#  {'_id': ObjectId('66e8140c8bad1c495d53a3b7'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x2162c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53c222'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x3202c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53c6e3'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x3a03c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53e64f'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x480cc50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53cccc'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x4bf8c40f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53d1c8'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x4f0ff519',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53f0ee'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x5616c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53e755'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x56fdc40f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53c521'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x580dc50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53b2fc'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x6902dd18',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53db66'),
#   'interface_type': 'EMMC',
#   'model': 'DA4032',
#   'serial_number': '0x6aa02b1b',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 5.82421875},
#  {'_id': ObjectId('66e8140c8bad1c495d53ed9f'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x7e15c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53e3a8'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x7e51261a',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53b43e'),
#   'interface_type': 'EMMC',
#   'model': 'DA4032',
#   'serial_number': '0x81377042',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 5.82421875},
#  {'_id': ObjectId('66e8140c8bad1c495d53bcb2'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x8192c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53a4bb'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x890cc50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53eadb'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x8b15c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53befe'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x9801c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53e09a'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x9a02c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53da38'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0x9c85c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53e7b5'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xa60dc50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53cde8'),
#   'interface_type': 'EMMC',
#   'model': 'MAG2GC',
#   'serial_number': '0xab05beaa',
#   'raw_capacity': 15634268160,
#   'capacity_gb': 14.560546875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 2.912109375},
#  {'_id': ObjectId('66e8140c8bad1c495d53d269'),
#   'interface_type': 'EMMC',
#   'model': 'MAG2GC',
#   'serial_number': '0xb09cb812',
#   'raw_capacity': 15634268160,
#   'capacity_gb': 14.560546875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 2.912109375},
#  {'_id': ObjectId('66e8140c8bad1c495d53af61'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xb342c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53c1f1'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xbba02841',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53aea9'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xc116c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53dec9'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xc501c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53e3ba'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xc501c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53af5b'),
#   'interface_type': 'EMMC',
#   'model': 'HAG2e',
#   'serial_number': '0xc89871be',
#   'raw_capacity': 15762194432,
#   'capacity_gb': 14.6796875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 2.9359375},
#  {'_id': ObjectId('66e8140c8bad1c495d53d087'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xd816c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53e71f'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xdc01c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53c0e8'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xdf0dc50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53e927'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xe79ec50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53c376'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xec08c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53dba8'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xec9ec50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53c1ab'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xeea82841',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53cfc6'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xf101c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53b73b'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xfc0bc50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53a892'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xfd08c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53d1b0'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '0xfd85c50f',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:05:00',
#   'elapsed_time_seconds': 300,
#   'erasure_rate': 11.6484375},
#  {'_id': ObjectId('66e8140c8bad1c495d53ab20'),
#   'interface_type': 'EMMC',
#   'model': 'MDGAGC',
#   'serial_number': '1018905342',
#   'raw_capacity': 125069950976,
#   'capacity_gb': 116.48046875,
#   'raw_elapsed_time': '00:32:42',
#   'elapsed_time_seconds': 1962,
#   'erasure_rate': 3.562093845565749},
#  {'_id': ObjectId('66e8140c8bad1c495d53b8ee'),
#   'interface_type': 'EMMC',
#   'model': 'MDGAGC',
#   'serial_number': '1018905352',
#   'raw_capacity': 125069950976,
#   'capacity_gb': 116.48046875,
#   'raw_elapsed_time': '00:44:19',
#   'elapsed_time_seconds': 2659,
#   'erasure_rate': 2.6283671022940953},
#  {'_id': ObjectId('66e8140c8bad1c495d53d313'),
#   'interface_type': 'EMMC',
#   'model': 'MDGAGC',
#   'serial_number': '1018905374',
#   'raw_capacity': 125069950976,
#   'capacity_gb': 116.48046875,
#   'raw_elapsed_time': '00:32:30',
#   'elapsed_time_seconds': 1950,
#   'erasure_rate': 3.584014423076923},
#  {'_id': ObjectId('66e8140c8bad1c495d53a3ab'),
#   'interface_type': 'EMMC',
#   'model': 'MMC32G',
#   'serial_number': '10320102',
#   'raw_capacity': 30601641984,
#   'capacity_gb': 28.5,
#   'raw_elapsed_time': '01:13:34',
#   'elapsed_time_seconds': 4414,
#   'erasure_rate': 0.38740371545083824},
#  {'_id': ObjectId('66e8140c8bad1c495d53a3ab'),
#   'interface_type': 'EMMC',
#   'model': 'MMC32G',
#   'serial_number': '10320102',
#   'raw_capacity': 30601641984,
#   'capacity_gb': 28.5,
#   'raw_elapsed_time': '00:36:23',
#   'elapsed_time_seconds': 2183,
#   'erasure_rate': 0.7833256985799358},
#  {'_id': ObjectId('66e8140c8bad1c495d53b4fc'),
#   'interface_type': 'EMMC',
#   'model': 'Biwin',
#   'serial_number': '104',
#   'raw_capacity': 61907927040,
#   'capacity_gb': 57.65625,
#   'raw_elapsed_time': '00:35:48',
#   'elapsed_time_seconds': 2148,
#   'erasure_rate': 1.610509776536313},
#  {'_id': ObjectId('66e8140c8bad1c495d53af80'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '1055619096',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:25:56',
#   'elapsed_time_seconds': 1556,
#   'erasure_rate': 2.245842705655527},
#  {'_id': ObjectId('66e8140c8bad1c495d53ddd7'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '1059136018',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:21',
#   'elapsed_time_seconds': 201,
#   'erasure_rate': 2.174035826725746},
#  {'_id': ObjectId('66e8140c8bad1c495d53cb4b'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '1060446738',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:28',
#   'elapsed_time_seconds': 208,
#   'erasure_rate': 2.1008711594801683},
#  {'_id': ObjectId('66e8140c8bad1c495d53c31f'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '1092559378',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:23',
#   'elapsed_time_seconds': 203,
#   'erasure_rate': 2.1526167545412562},
#  {'_id': ObjectId('66e8140c8bad1c495d53dd8b'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '1092690450',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:29',
#   'elapsed_time_seconds': 209,
#   'erasure_rate': 2.090819144363038},
#  {'_id': ObjectId('66e8140c8bad1c495d53d0b7'),
#   'interface_type': 'EMMC',
#   'model': 'DF4032',
#   'serial_number': '1124316988',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:20:02',
#   'elapsed_time_seconds': 1202,
#   'erasure_rate': 1.4536319675540763},
#  {'_id': ObjectId('66e8140c8bad1c495d53ca03'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '119611922',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:27',
#   'elapsed_time_seconds': 207,
#   'erasure_rate': 2.111020295516304},
#  {'_id': ObjectId('66e8140c8bad1c495d53ba59'),
#   'interface_type': 'EMMC',
#   'model': 'MMC32G',
#   'serial_number': '12099326',
#   'raw_capacity': 30601641984,
#   'capacity_gb': 28.5,
#   'raw_elapsed_time': '01:09:44',
#   'elapsed_time_seconds': 4184,
#   'erasure_rate': 0.40869980879541107},
#  {'_id': ObjectId('66e8140c8bad1c495d53ba59'),
#   'interface_type': 'EMMC',
#   'model': 'MMC32G',
#   'serial_number': '12099326',
#   'raw_capacity': 30601641984,
#   'capacity_gb': 28.5,
#   'raw_elapsed_time': '00:36:27',
#   'elapsed_time_seconds': 2187,
#   'erasure_rate': 0.7818930041152263},
#  {'_id': ObjectId('66e8140c8bad1c495d53c303'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '1244996114',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:20',
#   'elapsed_time_seconds': 200,
#   'erasure_rate': 2.184906005859375},
#  {'_id': ObjectId('66e8140c8bad1c495d53c02d'),
#   'interface_type': 'EMMC',
#   'model': 'SD16G',
#   'serial_number': '129473536',
#   'raw_capacity': 16022241280,
#   'capacity_gb': 14.921875,
#   'raw_elapsed_time': '00:21:36',
#   'elapsed_time_seconds': 1296,
#   'erasure_rate': 0.6908275462962963},
#  {'_id': ObjectId('66e8140c8bad1c495d53c281'),
#   'interface_type': 'EMMC',
#   'model': 'M62704',
#   'serial_number': '13002665',
#   'raw_capacity': 3791650816,
#   'capacity_gb': 3.53125,
#   'raw_elapsed_time': '00:05:46',
#   'elapsed_time_seconds': 346,
#   'erasure_rate': 0.6123554913294798},
#  {'_id': ObjectId('66e8140c8bad1c495d53afaf'),
#   'interface_type': 'EMMC',
#   'model': 'SD16Ga',
#   'serial_number': '134390529',
#   'raw_capacity': 15476981760,
#   'capacity_gb': 14.4140625,
#   'raw_elapsed_time': '00:40:57',
#   'elapsed_time_seconds': 2457,
#   'erasure_rate': 0.3519917582417582},
#  {'_id': ObjectId('66e8140c8bad1c495d53afaf'),
#   'interface_type': 'EMMC',
#   'model': 'SD16Ga',
#   'serial_number': '134390529',
#   'raw_capacity': 15476981760,
#   'capacity_gb': 14.4140625,
#   'raw_elapsed_time': '00:34:31',
#   'elapsed_time_seconds': 2071,
#   'erasure_rate': 0.4175971752776437},
#  {'_id': ObjectId('66e8140c8bad1c495d53a972'),
#   'interface_type': 'EMMC',
#   'model': 'DF4032',
#   'serial_number': '1348695555',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:18:59',
#   'elapsed_time_seconds': 1139,
#   'erasure_rate': 1.5340347892888497},
#  {'_id': ObjectId('66e8140c8bad1c495d53ae0b'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '1362502162',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:23',
#   'elapsed_time_seconds': 203,
#   'erasure_rate': 2.1526167545412562},
#  {'_id': ObjectId('66e8140c8bad1c495d53e471'),
#   'interface_type': 'EMMC',
#   'model': 'TX2964',
#   'serial_number': '1364300956',
#   'raw_capacity': 62587404288,
#   'capacity_gb': 58.2890625,
#   'raw_elapsed_time': '00:15:23',
#   'elapsed_time_seconds': 923,
#   'erasure_rate': 3.789104821235103},
#  {'_id': ObjectId('66e8140c8bad1c495d53a71e'),
#   'interface_type': 'EMMC',
#   'model': 'TX2964',
#   'serial_number': '1375272922',
#   'raw_capacity': 62587404288,
#   'capacity_gb': 58.2890625,
#   'raw_elapsed_time': '00:15:34',
#   'elapsed_time_seconds': 934,
#   'erasure_rate': 3.7444793897216275},
#  {'_id': ObjectId('66e8140c8bad1c495d53d303'),
#   'interface_type': 'EMMC',
#   'model': 'TX2964',
#   'serial_number': '1383622823',
#   'raw_capacity': 62587404288,
#   'capacity_gb': 58.2890625,
#   'raw_elapsed_time': '00:14:59',
#   'elapsed_time_seconds': 899,
#   'erasure_rate': 3.8902600111234706},
#  {'_id': ObjectId('66e8140c8bad1c495d53b961'),
#   'interface_type': 'EMMC',
#   'model': 'HBG8a4',
#   'serial_number': '1384292620',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:17:00',
#   'elapsed_time_seconds': 1020,
#   'erasure_rate': 1.7130055147058822},
#  {'_id': ObjectId('66e8140c8bad1c495d53dd13'),
#   'interface_type': 'EMMC',
#   'model': 'HBG4e',
#   'serial_number': '142337125',
#   'raw_capacity': 31272730624,
#   'capacity_gb': 29.125,
#   'raw_elapsed_time': '00:09:56',
#   'elapsed_time_seconds': 596,
#   'erasure_rate': 2.932046979865772},
#  {'_id': ObjectId('66e8140c8bad1c495d53e04e'),
#   'interface_type': 'EMMC',
#   'model': 'HBG4e',
#   'serial_number': '144044213',
#   'raw_capacity': 31272730624,
#   'capacity_gb': 29.125,
#   'raw_elapsed_time': '00:12:10',
#   'elapsed_time_seconds': 730,
#   'erasure_rate': 2.393835616438356},
#  {'_id': ObjectId('66e8140c8bad1c495d53dacd'),
#   'interface_type': 'EMMC',
#   'model': 'HBG4e',
#   'serial_number': '1450814924',
#   'raw_capacity': 31272730624,
#   'capacity_gb': 29.125,
#   'raw_elapsed_time': '00:09:50',
#   'elapsed_time_seconds': 590,
#   'erasure_rate': 2.961864406779661},
#  {'_id': ObjectId('66e8140c8bad1c495d53dceb'),
#   'interface_type': 'EMMC',
#   'model': 'HBG4e',
#   'serial_number': '1450815017',
#   'raw_capacity': 31272730624,
#   'capacity_gb': 29.125,
#   'raw_elapsed_time': '00:08:12',
#   'elapsed_time_seconds': 492,
#   'erasure_rate': 3.5518292682926833},
#  {'_id': ObjectId('66e8140c8bad1c495d53c141'),
#   'interface_type': 'EMMC',
#   'model': 'CGND3R',
#   'serial_number': '1483040011',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:12:40',
#   'elapsed_time_seconds': 760,
#   'erasure_rate': 4.5980674342105265},
#  {'_id': ObjectId('66e8140c8bad1c495d53c9e1'),
#   'interface_type': 'EMMC',
#   'model': 'HBG4e',
#   'serial_number': '1484450209',
#   'raw_capacity': 31272730624,
#   'capacity_gb': 29.125,
#   'raw_elapsed_time': '00:07:33',
#   'elapsed_time_seconds': 453,
#   'erasure_rate': 3.857615894039735},
#  {'_id': ObjectId('66e8140c8bad1c495d53c71e'),
#   'interface_type': 'EMMC',
#   'model': 'HCG4a2',
#   'serial_number': '1501183423',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:09:46',
#   'elapsed_time_seconds': 586,
#   'erasure_rate': 5.963363907849829},
#  {'_id': ObjectId('66e8140c8bad1c495d53bd0d'),
#   'interface_type': 'EMMC',
#   'model': 'HCG4a2',
#   'serial_number': '1501183516',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:09:05',
#   'elapsed_time_seconds': 545,
#   'erasure_rate': 6.411983944954128},
#  {'_id': ObjectId('66e8140c8bad1c495d53d8f6'),
#   'interface_type': 'EMMC',
#   'model': 'HBG4a2',
#   'serial_number': '1504368920',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:04:44',
#   'elapsed_time_seconds': 284,
#   'erasure_rate': 6.15234375},
#  {'_id': ObjectId('66e8140c8bad1c495d53e344'),
#   'interface_type': 'EMMC',
#   'model': 'HBG4a2',
#   'serial_number': '1504375889',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:04:49',
#   'elapsed_time_seconds': 289,
#   'erasure_rate': 6.045901816608997},
#  {'_id': ObjectId('66e8140c8bad1c495d53a2fb'),
#   'interface_type': 'EMMC',
#   'model': 'HBG4a2',
#   'serial_number': '1504375903',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:04:54',
#   'elapsed_time_seconds': 294,
#   'erasure_rate': 5.943080357142857},
#  {'_id': ObjectId('66e8140c8bad1c495d53f179'),
#   'interface_type': 'EMMC',
#   'model': 'HBG4a2',
#   'serial_number': '1504376002',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:04:46',
#   'elapsed_time_seconds': 286,
#   'erasure_rate': 6.1093203671328675},
#  {'_id': ObjectId('66e8140c8bad1c495d53e976'),
#   'interface_type': 'EMMC',
#   'model': 'HBG4a2',
#   'serial_number': '1504376008',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:04:38',
#   'elapsed_time_seconds': 278,
#   'erasure_rate': 6.2851281474820135},
#  {'_id': ObjectId('66e8140c8bad1c495d53c32d'),
#   'interface_type': 'EMMC',
#   'model': 'TA2964',
#   'serial_number': '1507251897',
#   'raw_capacity': 62612570112,
#   'capacity_gb': 58.3125,
#   'raw_elapsed_time': '00:24:52',
#   'elapsed_time_seconds': 1492,
#   'erasure_rate': 2.3450067024128685},
#  {'_id': ObjectId('66e8140c8bad1c495d53d445'),
#   'interface_type': 'EMMC',
#   'model': '032G92',
#   'serial_number': '1507872245',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:35:51',
#   'elapsed_time_seconds': 2151,
#   'erasure_rate': 0.812303870292887},
#  {'_id': ObjectId('66e8140c8bad1c495d53b9fd'),
#   'interface_type': 'EMMC',
#   'model': 'TA2964',
#   'serial_number': '1515643206',
#   'raw_capacity': 62612570112,
#   'capacity_gb': 58.3125,
#   'raw_elapsed_time': '00:24:58',
#   'elapsed_time_seconds': 1498,
#   'erasure_rate': 2.3356141522029374},
#  {'_id': ObjectId('66e8140c8bad1c495d53c2c3'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '153100818',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:28',
#   'elapsed_time_seconds': 208,
#   'erasure_rate': 2.1008711594801683},
#  {'_id': ObjectId('66e8140c8bad1c495d53d991'),
#   'interface_type': 'EMMC',
#   'model': 'MMC32G',
#   'serial_number': '15467152',
#   'raw_capacity': 30601641984,
#   'capacity_gb': 28.5,
#   'raw_elapsed_time': '01:13:28',
#   'elapsed_time_seconds': 4408,
#   'erasure_rate': 0.3879310344827586},
#  {'_id': ObjectId('66e8140c8bad1c495d53d991'),
#   'interface_type': 'EMMC',
#   'model': 'MMC32G',
#   'serial_number': '15467152',
#   'raw_capacity': 30601641984,
#   'capacity_gb': 28.5,
#   'raw_elapsed_time': '00:36:26',
#   'elapsed_time_seconds': 2186,
#   'erasure_rate': 0.7822506861848125},
#  {'_id': ObjectId('66e8140c8bad1c495d53d5cc'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '1658094914',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:43:25',
#   'elapsed_time_seconds': 2605,
#   'erasure_rate': 1.3414707293666028},
#  {'_id': ObjectId('66e8140c8bad1c495d53cc0b'),
#   'interface_type': 'EMMC',
#   'model': 'G1J38E',
#   'serial_number': '166545745',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:18:12',
#   'elapsed_time_seconds': 1092,
#   'erasure_rate': 3.2001201923076925},
#  {'_id': ObjectId('66e8140c8bad1c495d53d67c'),
#   'interface_type': 'EMMC',
#   'model': 'G1J38E',
#   'serial_number': '166720821',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:17:01',
#   'elapsed_time_seconds': 1021,
#   'erasure_rate': 3.4226554848188053},
#  {'_id': ObjectId('66e8140c8bad1c495d53dd22'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '1706788634',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:24:34',
#   'elapsed_time_seconds': 1474,
#   'erasure_rate': 2.370781037991859},
#  {'_id': ObjectId('66e8140c8bad1c495d53f085'),
#   'interface_type': 'EMMC',
#   'model': 'DF4032',
#   'serial_number': '173642954',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:20:16',
#   'elapsed_time_seconds': 1216,
#   'erasure_rate': 1.4368960731907896},
#  {'_id': ObjectId('66e8140c8bad1c495d53d2dd'),
#   'interface_type': 'EMMC',
#   'model': 'DF4032',
#   'serial_number': '1836085251',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:19:01',
#   'elapsed_time_seconds': 1141,
#   'erasure_rate': 1.5313458588957056},
#  {'_id': ObjectId('66e8140c8bad1c495d53bce7'),
#   'interface_type': 'EMMC',
#   'model': 'BJNB4R',
#   'serial_number': '1839621357',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:12:35',
#   'elapsed_time_seconds': 755,
#   'erasure_rate': 2.314259105960265},
#  {'_id': ObjectId('66e8140c8bad1c495d53a582'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '188097042',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:21',
#   'elapsed_time_seconds': 201,
#   'erasure_rate': 2.174035826725746},
#  {'_id': ObjectId('66e8140c8bad1c495d53d993'),
#   'interface_type': 'EMMC',
#   'model': 'MMC32G',
#   'serial_number': '19380194',
#   'raw_capacity': 30601641984,
#   'capacity_gb': 28.5,
#   'raw_elapsed_time': '01:13:42',
#   'elapsed_time_seconds': 4422,
#   'erasure_rate': 0.3867028493894165},
#  {'_id': ObjectId('66e8140c8bad1c495d53d993'),
#   'interface_type': 'EMMC',
#   'model': 'MMC32G',
#   'serial_number': '19380194',
#   'raw_capacity': 30601641984,
#   'capacity_gb': 28.5,
#   'raw_elapsed_time': '00:35:52',
#   'elapsed_time_seconds': 2152,
#   'erasure_rate': 0.7946096654275093},
#  {'_id': ObjectId('66e8140c8bad1c495d53dd85'),
#   'interface_type': 'EMMC',
#   'model': 'MMC32G',
#   'serial_number': '19380212',
#   'raw_capacity': 30601641984,
#   'capacity_gb': 28.5,
#   'raw_elapsed_time': '01:11:39',
#   'elapsed_time_seconds': 4299,
#   'erasure_rate': 0.3977669225401256},
#  {'_id': ObjectId('66e8140c8bad1c495d53dd85'),
#   'interface_type': 'EMMC',
#   'model': 'MMC32G',
#   'serial_number': '19380212',
#   'raw_capacity': 30601641984,
#   'capacity_gb': 28.5,
#   'raw_elapsed_time': '00:36:35',
#   'elapsed_time_seconds': 2195,
#   'erasure_rate': 0.7790432801822323},
#  {'_id': ObjectId('66e8140c8bad1c495d53a540'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '1949704722',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:19',
#   'elapsed_time_seconds': 199,
#   'erasure_rate': 2.1958854330244972},
#  {'_id': ObjectId('66e8140c8bad1c495d53d687'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '2134123026',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:27',
#   'elapsed_time_seconds': 207,
#   'erasure_rate': 2.111020295516304},
#  {'_id': ObjectId('66e8140c8bad1c495d53e50a'),
#   'interface_type': 'EMMC',
#   'model': 'M62704',
#   'serial_number': '21394834',
#   'raw_capacity': 3791650816,
#   'capacity_gb': 3.53125,
#   'raw_elapsed_time': '00:05:45',
#   'elapsed_time_seconds': 345,
#   'erasure_rate': 0.6141304347826086},
#  {'_id': ObjectId('66e8140c8bad1c495d53b349'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '2164518678',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:33:40',
#   'elapsed_time_seconds': 2020,
#   'erasure_rate': 1.7299659653465347},
#  {'_id': ObjectId('66e8140c8bad1c495d53d336'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '2201231890',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:26',
#   'elapsed_time_seconds': 206,
#   'erasure_rate': 2.1212679668537624},
#  {'_id': ObjectId('66e8140c8bad1c495d53b94a'),
#   'interface_type': 'EMMC',
#   'model': 'NCard',
#   'serial_number': '2216591193',
#   'raw_capacity': 31037849600,
#   'capacity_gb': 28.90625,
#   'raw_elapsed_time': '00:40:49',
#   'elapsed_time_seconds': 2449,
#   'erasure_rate': 0.708197223356472},
#  {'_id': ObjectId('66e8140c8bad1c495d53baad'),
#   'interface_type': 'EMMC',
#   'model': 'DF4032',
#   'serial_number': '224884227',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '01:12:24',
#   'elapsed_time_seconds': 4344,
#   'erasure_rate': 0.4022250517955801},
#  {'_id': ObjectId('66e8140c8bad1c495d53e1a4'),
#   'interface_type': 'EMMC',
#   'model': 'DF4032',
#   'serial_number': '2254607482',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:20:14',
#   'elapsed_time_seconds': 1214,
#   'erasure_rate': 1.4392632825370675},
#  {'_id': ObjectId('66e8140c8bad1c495d53d05e'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '2268340754',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:27',
#   'elapsed_time_seconds': 207,
#   'erasure_rate': 2.111020295516304},
#  {'_id': ObjectId('66e8140c8bad1c495d53e5ab'),
#   'interface_type': 'EMMC',
#   'model': 'SEM128',
#   'serial_number': '234655227',
#   'raw_capacity': 125074145280,
#   'capacity_gb': 116.484375,
#   'raw_elapsed_time': '01:35:09',
#   'elapsed_time_seconds': 5709,
#   'erasure_rate': 1.224218339464004},
#  {'_id': ObjectId('66e8140c8bad1c495d53bba7'),
#   'interface_type': 'EMMC',
#   'model': 'DF4064',
#   'serial_number': '2404234762',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:41:38',
#   'elapsed_time_seconds': 2498,
#   'erasure_rate': 1.398931645316253},
#  {'_id': ObjectId('66e8140c8bad1c495d53e054'),
#   'interface_type': 'EMMC',
#   'model': 'MDGAGC',
#   'serial_number': '2460436522',
#   'raw_capacity': 125069950976,
#   'capacity_gb': 116.48046875,
#   'raw_elapsed_time': '00:37:41',
#   'elapsed_time_seconds': 2261,
#   'erasure_rate': 3.0910341110128265},
#  {'_id': ObjectId('66e8140c8bad1c495d53d500'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '2535399954',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:23',
#   'elapsed_time_seconds': 203,
#   'erasure_rate': 2.1526167545412562},
#  {'_id': ObjectId('66e8140c8bad1c495d53b468'),
#   'interface_type': 'EMMC',
#   'model': 'SDW32G',
#   'serial_number': '255018936',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:10:28',
#   'elapsed_time_seconds': 628,
#   'erasure_rate': 2.7822701035031847},
#  {'_id': ObjectId('66e8140c8bad1c495d53be9f'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '2553553426',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:21',
#   'elapsed_time_seconds': 201,
#   'erasure_rate': 2.174035826725746},
#  {'_id': ObjectId('66e8140c8bad1c495d53ae12'),
#   'interface_type': 'EMMC',
#   'model': '032G92',
#   'serial_number': '2556445519',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:37:19',
#   'elapsed_time_seconds': 2239,
#   'erasure_rate': 0.7803776797677534},
#  {'_id': ObjectId('66e8140c8bad1c495d53b24d'),
#   'interface_type': 'EMMC',
#   'model': 'BGND3R',
#   'serial_number': '2578380987',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:19:01',
#   'elapsed_time_seconds': 1141,
#   'erasure_rate': 1.5313458588957056},
#  {'_id': ObjectId('66e8140c8bad1c495d53b46e'),
#   'interface_type': 'EMMC',
#   'model': 'DF4032',
#   'serial_number': '2585573180',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:19:20',
#   'elapsed_time_seconds': 1160,
#   'erasure_rate': 1.5062634698275863},
#  {'_id': ObjectId('66e8140c8bad1c495d53eac0'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '2603885074',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:22',
#   'elapsed_time_seconds': 202,
#   'erasure_rate': 2.163273273128094},
#  {'_id': ObjectId('66e8140c8bad1c495d53b8bc'),
#   'interface_type': 'EMMC',
#   'model': 'BJNB4R',
#   'serial_number': '2640509546',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:10:04',
#   'elapsed_time_seconds': 604,
#   'erasure_rate': 2.8928238824503314},
#  {'_id': ObjectId('66e8140c8bad1c495d53adc3'),
#   'interface_type': 'EMMC',
#   'model': '032G92',
#   'serial_number': '2653202842',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:42:57',
#   'elapsed_time_seconds': 2577,
#   'erasure_rate': 0.6780231373690337},
#  {'_id': ObjectId('66e8140c8bad1c495d53ab22'),
#   'interface_type': 'EMMC',
#   'model': 'SDU1',
#   'serial_number': '2685674241',
#   'raw_capacity': 126437294080,
#   'capacity_gb': 117.75390625,
#   'raw_elapsed_time': '00:27:20',
#   'elapsed_time_seconds': 1640,
#   'erasure_rate': 4.308069740853659},
#  {'_id': ObjectId('66e8140c8bad1c495d53ab22'),
#   'interface_type': 'EMMC',
#   'model': 'SDU1',
#   'serial_number': '2685674241',
#   'raw_capacity': 126437294080,
#   'capacity_gb': 117.75390625,
#   'raw_elapsed_time': '01:46:11',
#   'elapsed_time_seconds': 6371,
#   'erasure_rate': 1.1089678818081934},
#  {'_id': ObjectId('66e8140c8bad1c495d53ec41'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '2704613906',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:22',
#   'elapsed_time_seconds': 202,
#   'erasure_rate': 2.163273273128094},
#  {'_id': ObjectId('66e8140c8bad1c495d53be54'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '2736726546',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:24',
#   'elapsed_time_seconds': 204,
#   'erasure_rate': 2.1420647116268383},
#  {'_id': ObjectId('66e8140c8bad1c495d53d07b'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '2802590226',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:26',
#   'elapsed_time_seconds': 206,
#   'erasure_rate': 2.1212679668537624},
#  {'_id': ObjectId('66e8140c8bad1c495d53c4c9'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '2803835410',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:26',
#   'elapsed_time_seconds': 206,
#   'erasure_rate': 2.1212679668537624},
#  {'_id': ObjectId('66e8140c8bad1c495d53d55e'),
#   'interface_type': 'EMMC',
#   'model': 'DF4064',
#   'serial_number': '2850783495',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:32:43',
#   'elapsed_time_seconds': 1963,
#   'erasure_rate': 1.7801993122771267},
#  {'_id': ObjectId('66e8140c8bad1c495d53e295'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '2976785426',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:27',
#   'elapsed_time_seconds': 207,
#   'erasure_rate': 2.111020295516304},
#  {'_id': ObjectId('66e8140c8bad1c495d53b3a1'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '3005162002',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:23',
#   'elapsed_time_seconds': 203,
#   'erasure_rate': 2.1526167545412562},
#  {'_id': ObjectId('66e8140c8bad1c495d53e98e'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '3021939218',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:22',
#   'elapsed_time_seconds': 202,
#   'erasure_rate': 2.163273273128094},
#  {'_id': ObjectId('66e8140c8bad1c495d53ca3d'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '3054314002',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:25',
#   'elapsed_time_seconds': 205,
#   'erasure_rate': 2.131615615472561},
#  {'_id': ObjectId('66e8140c8bad1c495d53bfda'),
#   'interface_type': 'EMMC',
#   'model': 'DF4032',
#   'serial_number': '3173749511',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:20:08',
#   'elapsed_time_seconds': 1208,
#   'erasure_rate': 1.4464119412251657},
#  {'_id': ObjectId('66e8140c8bad1c495d53b412'),
#   'interface_type': 'EMMC',
#   'model': 'DF4032',
#   'serial_number': '3177608707',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:18:50',
#   'elapsed_time_seconds': 1130,
#   'erasure_rate': 1.5462527654867257},
#  {'_id': ObjectId('66e8140c8bad1c495d53d446'),
#   'interface_type': 'EMMC',
#   'model': 'DF4032',
#   'serial_number': '3256850450',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:21:48',
#   'elapsed_time_seconds': 1308,
#   'erasure_rate': 1.33582998853211},
#  {'_id': ObjectId('66e8140c8bad1c495d53b807'),
#   'interface_type': 'EMMC',
#   'model': '064G38',
#   'serial_number': '3356920086',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:29:46',
#   'elapsed_time_seconds': 1786,
#   'erasure_rate': 1.9566244400895858},
#  {'_id': ObjectId('66e8140c8bad1c495d53b75e'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '3409151514',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:22:15',
#   'elapsed_time_seconds': 1335,
#   'erasure_rate': 2.617626404494382},
#  {'_id': ObjectId('66e8140c8bad1c495d53d984'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '3422520602',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:23:21',
#   'elapsed_time_seconds': 1401,
#   'erasure_rate': 2.4943120985010707},
#  {'_id': ObjectId('66e8140c8bad1c495d53da45'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '3493143058',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:20',
#   'elapsed_time_seconds': 200,
#   'erasure_rate': 2.184906005859375},
#  {'_id': ObjectId('66e8140c8bad1c495d53e6eb'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '3509854738',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:22',
#   'elapsed_time_seconds': 202,
#   'erasure_rate': 2.163273273128094},
#  {'_id': ObjectId('66e8140c8bad1c495d53b9c1'),
#   'interface_type': 'EMMC',
#   'model': 'DF4064',
#   'serial_number': '356352007',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:31:58',
#   'elapsed_time_seconds': 1918,
#   'erasure_rate': 1.8219662408759125},
#  {'_id': ObjectId('66e8140c8bad1c495d53cb22'),
#   'interface_type': 'EMMC',
#   'model': 'CUTB42',
#   'serial_number': '3565011107',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:09:22',
#   'elapsed_time_seconds': 562,
#   'erasure_rate': 6.218027135231316},
#  {'_id': ObjectId('66e8140c8bad1c495d53c69e'),
#   'interface_type': 'EMMC',
#   'model': '032G92',
#   'serial_number': '3607768110',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:45:48',
#   'elapsed_time_seconds': 2748,
#   'erasure_rate': 0.6358317412663755},
#  {'_id': ObjectId('66e8140c8bad1c495d53c35b'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '3627295250',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:28',
#   'elapsed_time_seconds': 208,
#   'erasure_rate': 2.1008711594801683},
#  {'_id': ObjectId('66e8140c8bad1c495d53df9a'),
#   'interface_type': 'EMMC',
#   'model': 'BJNB4R',
#   'serial_number': '3657351229',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:18:05',
#   'elapsed_time_seconds': 1085,
#   'erasure_rate': 1.6103830645161292},
#  {'_id': ObjectId('66e8140c8bad1c495d53c2eb'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '3660849682',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:25',
#   'elapsed_time_seconds': 205,
#   'erasure_rate': 2.131615615472561},
#  {'_id': ObjectId('66e8140c8bad1c495d53bfc4'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '3711181330',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:27',
#   'elapsed_time_seconds': 207,
#   'erasure_rate': 2.111020295516304},
#  {'_id': ObjectId('66e8140c8bad1c495d53ec15'),
#   'interface_type': 'EMMC',
#   'model': 'SL64G',
#   'serial_number': '3729009153',
#   'raw_capacity': 63864569856,
#   'capacity_gb': 59.478515625,
#   'raw_elapsed_time': '01:28:42',
#   'elapsed_time_seconds': 5322,
#   'erasure_rate': 0.6705582370349492},
#  {'_id': ObjectId('66e8140c8bad1c495d53ec15'),
#   'interface_type': 'EMMC',
#   'model': 'SL64G',
#   'serial_number': '3729009153',
#   'raw_capacity': 63864569856,
#   'capacity_gb': 59.478515625,
#   'raw_elapsed_time': '00:53:54',
#   'elapsed_time_seconds': 3234,
#   'erasure_rate': 1.1034975069573285},
#  {'_id': ObjectId('66e8140c8bad1c495d53d770'),
#   'interface_type': 'EMMC',
#   'model': 'BJNB4R',
#   'serial_number': '373026436',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:10:27',
#   'elapsed_time_seconds': 627,
#   'erasure_rate': 2.7867075358851676},
#  {'_id': ObjectId('66e8140c8bad1c495d53bf4c'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '3731760146',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:28',
#   'elapsed_time_seconds': 208,
#   'erasure_rate': 2.1008711594801683},
#  {'_id': ObjectId('66e8140c8bad1c495d53d9ad'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '374569496',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:29:07',
#   'elapsed_time_seconds': 1747,
#   'erasure_rate': 2.000304092730395},
#  {'_id': ObjectId('66e8140c8bad1c495d53b400'),
#   'interface_type': 'EMMC',
#   'model': 'UY5CS0',
#   'serial_number': '3759276485',
#   'raw_capacity': 31406948352,
#   'capacity_gb': 29.25,
#   'raw_elapsed_time': '00:28:55',
#   'elapsed_time_seconds': 1735,
#   'erasure_rate': 1.0115273775216138},
#  {'_id': ObjectId('66e8140c8bad1c495d53ab91'),
#   'interface_type': 'EMMC',
#   'model': 'UY5CS0',
#   'serial_number': '3759276690',
#   'raw_capacity': 31406948352,
#   'capacity_gb': 29.25,
#   'raw_elapsed_time': '00:29:33',
#   'elapsed_time_seconds': 1773,
#   'erasure_rate': 0.9898477157360406},
#  {'_id': ObjectId('66e8140c8bad1c495d53b71c'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '3765314578',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:23',
#   'elapsed_time_seconds': 203,
#   'erasure_rate': 2.1526167545412562},
#  {'_id': ObjectId('66e8140c8bad1c495d53edfe'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '3778290194',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:27',
#   'elapsed_time_seconds': 207,
#   'erasure_rate': 2.111020295516304},
#  {'_id': ObjectId('66e8140c8bad1c495d53c0a0'),
#   'interface_type': 'EMMC',
#   'model': 'DG4008',
#   'serial_number': '3778355730',
#   'raw_capacity': 7820083200,
#   'capacity_gb': 7.28302001953125,
#   'raw_elapsed_time': '00:03:30',
#   'elapsed_time_seconds': 210,
#   'erasure_rate': 2.0808628627232144},
#  {'_id': ObjectId('66e8140c8bad1c495d53afa1'),
#   'interface_type': 'EMMC',
#   'model': 'DF4032',
#   'serial_number': '387823420',
#   'raw_capacity': 31268536320,
#   'capacity_gb': 29.12109375,
#   'raw_elapsed_time': '00:23:46',
#   'elapsed_time_seconds': 1426,
#   'erasure_rate': 1.2252914621318374},
#  {'_id': ObjectId('66e8140c8bad1c495d53af3b'),
#   'interface_type': 'EMMC',
#   'model': 'DA4064',
#   'serial_number': '396375321',
#   'raw_capacity': 62537072640,
#   'capacity_gb': 58.2421875,
#   'raw_elapsed_time': '00:22:12',
#   'elapsed_time_seconds': 1332,
#   'erasure_rate': 2.6235219594594597},
#  {'_id': ObjectId('66e8140c8bad1c495d53ea1d'),
#   'interface_type': 'EMMC',
#   'serial_number': '403664384',
#   'raw_capacity': 16021192704,
#   'capacity_gb': 14.9208984375,
#   'raw_elapsed_time': '03:29:26',
#   'elapsed_time_seconds': 12566,
# ...
#   'erasure_rate': 6.929053872318591},
#  {'_id': ObjectId('66e8140c8bad1c495d53eef2'),
#   'interface_type': 'NVMe',
#   'model': 'KXG50ZNV256G TOSHIBA',
#   'serial_number': '97PB67CLK5VS',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:31:47',
#   'elapsed_time_seconds': 1907,
#   'erasure_rate': 7.503144334734079},
#  {'_id': ObjectId('66e8140c8bad1c495d53bb41'),
#   'interface_type': 'NVMe',
#   'model': 'KXG50ZNV256G TOSHIBA',
#   'serial_number': '97PB67CSK5VS',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:33:46',
#   'elapsed_time_seconds': 2026,
#   'erasure_rate': 7.062436449327685},
#  {'_id': ObjectId('66e8140c8bad1c495d53e394'),
#   'interface_type': 'NVMe',
#   'model': 'KXG50ZNV256G TOSHIBA',
#   'serial_number': '97PB67CZK5VS',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:34:46',
#   'elapsed_time_seconds': 2086,
#   'erasure_rate': 6.859298296422766},
#  {'_id': ObjectId('66e8140c8bad1c495d53ec8e'),
#   'interface_type': 'NVMe',
#   'model': 'KXG50ZNV256G TOSHIBA',
#   'serial_number': '97QB51AVK5VS',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:32:20',
#   'elapsed_time_seconds': 1940,
#   'erasure_rate': 7.375513529040149},
#  {'_id': ObjectId('66e8140c8bad1c495d53e1e5'),
#   'interface_type': 'NVMe',
#   'model': 'KBG30ZPZ128G TOSHIBA',
#   'serial_number': '981T203QPM1S',
#   'raw_capacity': 128035676160,
#   'capacity_gb': 119.24251556396484,
#   'raw_elapsed_time': '00:49:53',
#   'elapsed_time_seconds': 2993,
#   'erasure_rate': 2.390427976557932},
#  {'_id': ObjectId('66e8140c8bad1c495d53bc3a'),
#   'interface_type': 'NVMe',
#   'model': 'KBG30ZPZ128G TOSHIBA',
#   'serial_number': '984T10X3PM1S',
#   'raw_capacity': 128035676160,
#   'capacity_gb': 119.24251556396484,
#   'raw_elapsed_time': '00:47:20',
#   'elapsed_time_seconds': 2840,
#   'erasure_rate': 2.519208075295032},
#  {'_id': ObjectId('66e8140c8bad1c495d53b828'),
#   'interface_type': 'NVMe',
#   'model': 'KBG30ZMS256G NVMe TOSHIBA 256GB',
#   'serial_number': '98GPC1CQPWFP',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '02:04:01',
#   'elapsed_time_seconds': 7441,
#   'erasure_rate': 1.9229265214807003},
#  {'_id': ObjectId('66e8140c8bad1c495d53daad'),
#   'interface_type': 'NVMe',
#   'model': 'KXG50ZNV256G NVMe TOSHIBA 256GB',
#   'serial_number': '98QB80WSKAUP',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:34:36',
#   'elapsed_time_seconds': 2076,
#   'erasure_rate': 6.892339232340024},
#  {'_id': ObjectId('66e8140c8bad1c495d53c05f'),
#   'interface_type': 'NVMe',
#   'model': 'KXG50ZNV256G NVMe TOSHIBA 256GB',
#   'serial_number': '98QB80XDKAUP',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:38:58',
#   'elapsed_time_seconds': 2338,
#   'erasure_rate': 6.119972731538875},
#  {'_id': ObjectId('66e8140c8bad1c495d53aae1'),
#   'interface_type': 'NVMe',
#   'model': 'KXG50ZNV256G NVMe TOSHIBA 256GB',
#   'serial_number': '98QB81N8KAUP',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:34:05',
#   'elapsed_time_seconds': 2045,
#   'erasure_rate': 6.996819680360826},
#  {'_id': ObjectId('66e8140c8bad1c495d53f29b'),
#   'interface_type': 'NVMe',
#   'model': 'KBG30ZMV256G TOSHIBA',
#   'serial_number': '995PD8CEPZXP',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '01:52:13',
#   'elapsed_time_seconds': 6733,
#   'erasure_rate': 2.125129399426391},
#  {'_id': ObjectId('66e8140c8bad1c495d53e09e'),
#   'interface_type': 'NVMe',
#   'model': 'KBG40ZNS256G NVMe TOSHIBA 256GB',
#   'serial_number': '997PC7H8PQEN',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:34:24',
#   'elapsed_time_seconds': 2064,
#   'erasure_rate': 6.932410972062931},
#  {'_id': ObjectId('66e8140c8bad1c495d53f04e'),
#   'interface_type': 'NVMe',
#   'model': 'KXG6AZNV512G TOSHIBA',
#   'serial_number': '99AF71AGFU0N',
#   'raw_capacity': 512110190592,
#   'capacity_gb': 476.93978118896484,
#   'raw_elapsed_time': '00:28:59',
#   'elapsed_time_seconds': 1739,
#   'erasure_rate': 16.455656625266183},
#  {'_id': ObjectId('66e8140c8bad1c495d53a941'),
#   'interface_type': 'NVMe',
#   'model': 'KBG40ZNS256G NVMe TOSHIBA 256GB',
#   'serial_number': '99FPCF2LPQEN',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:21:34',
#   'elapsed_time_seconds': 1294,
#   'erasure_rate': 11.057570514944274},
#  {'_id': ObjectId('66e8140c8bad1c495d53a44c'),
#   'interface_type': 'NVMe',
#   'model': 'KBG40ZNS256G NVMe TOSHIBA 256GB',
#   'serial_number': '99FPCF5IPQEN',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:34:53',
#   'elapsed_time_seconds': 2093,
#   'erasure_rate': 6.836357499444764},
#  {'_id': ObjectId('66e8140c8bad1c495d53e34d'),
#   'interface_type': 'NVMe',
#   'model': 'KBG40ZNS256G NVMe TOSHIBA 256GB',
#   'serial_number': '99FPCF5WPQEN',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:47:02',
#   'elapsed_time_seconds': 2822,
#   'erasure_rate': 5.070338854123987},
#  {'_id': ObjectId('66e8140c8bad1c495d53be5c'),
#   'interface_type': 'NVMe',
#   'model': 'KXG60ZNV512G TOSHIBA',
#   'serial_number': '99KA13PEKRYN',
#   'raw_capacity': 512110190592,
#   'capacity_gb': 476.93978118896484,
#   'raw_elapsed_time': '00:31:43',
#   'elapsed_time_seconds': 1903,
#   'erasure_rate': 15.037512806798683},
#  {'_id': ObjectId('66e8140c8bad1c495d53e58c'),
#   'interface_type': 'NVMe',
#   'model': 'KXG60ZNV512G TOSHIBA',
#   'serial_number': '99KA145PKRYN',
#   'raw_capacity': 512110190592,
#   'capacity_gb': 476.93978118896484,
#   'raw_elapsed_time': '00:37:11',
#   'elapsed_time_seconds': 2231,
#   'erasure_rate': 12.826708593159074},
#  {'_id': ObjectId('66e8140c8bad1c495d53be02'),
#   'interface_type': 'NVMe',
#   'model': 'KXG60ZNV512G TOSHIBA',
#   'serial_number': '99KA14E5KRYN',
#   'raw_capacity': 512110190592,
#   'capacity_gb': 476.93978118896484,
#   'raw_elapsed_time': '00:33:13',
#   'elapsed_time_seconds': 1993,
#   'erasure_rate': 14.358448003681831},
#  {'_id': ObjectId('66e8140c8bad1c495d53b461'),
#   'interface_type': 'NVMe',
#   'model': 'KXG60ZNV512G TOSHIBA',
#   'serial_number': '99KA14FSKRYN',
#   'raw_capacity': 512110190592,
#   'capacity_gb': 476.93978118896484,
#   'raw_elapsed_time': '00:37:29',
#   'elapsed_time_seconds': 2249,
#   'erasure_rate': 12.724049298060422},
#  {'_id': ObjectId('66e8140c8bad1c495d53e185'),
#   'interface_type': 'NVMe',
#   'model': 'KXG60ZNV512G TOSHIBA',
#   'serial_number': '99KA20X2KRYN',
#   'raw_capacity': 512110190592,
#   'capacity_gb': 476.93978118896484,
#   'raw_elapsed_time': '00:29:20',
#   'elapsed_time_seconds': 1760,
#   'erasure_rate': 16.259310722351074},
#  {'_id': ObjectId('66e8140c8bad1c495d53d724'),
#   'interface_type': 'NVMe',
#   'model': 'KXG60ZNV512G TOSHIBA',
#   'serial_number': '99KA213LKRYN',
#   'raw_capacity': 512110190592,
#   'capacity_gb': 476.93978118896484,
#   'raw_elapsed_time': '00:31:25',
#   'elapsed_time_seconds': 1885,
#   'erasure_rate': 15.181107093547952},
#  {'_id': ObjectId('66e8140c8bad1c495d53ac45'),
#   'interface_type': 'NVMe',
#   'model': 'KXG60ZNV512G TOSHIBA',
#   'serial_number': '99KA213XKRYN',
#   'raw_capacity': 512110190592,
#   'capacity_gb': 476.93978118896484,
#   'raw_elapsed_time': '00:45:05',
#   'elapsed_time_seconds': 2705,
#   'erasure_rate': 10.579070932102733},
#  {'_id': ObjectId('66e8140c8bad1c495d53cf27'),
#   'interface_type': 'NVMe',
#   'model': 'KXG60ZNV512G TOSHIBA',
#   'serial_number': '99KA213XKRYN',
#   'raw_capacity': 512110190592,
#   'capacity_gb': 476.93978118896484,
#   'raw_elapsed_time': '00:28:16',
#   'elapsed_time_seconds': 1696,
#   'erasure_rate': 16.872869617534136},
#  {'_id': ObjectId('66e8140c8bad1c495d53a304'),
#   'interface_type': 'NVMe',
#   'model': 'KXG60ZNV512G TOSHIBA',
#   'serial_number': '99KA215MKRYN',
#   'raw_capacity': 512110190592,
#   'capacity_gb': 476.93978118896484,
#   'raw_elapsed_time': '00:38:58',
#   'elapsed_time_seconds': 2338,
#   'erasure_rate': 12.239686429143665},
#  {'_id': ObjectId('66e8140c8bad1c495d53dc6e'),
#   'interface_type': 'NVMe',
#   'model': 'PC601 NVMe SK hynix 256GB',
#   'serial_number': 'AD99N4523111Y9B11',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:26:47',
#   'elapsed_time_seconds': 1607,
#   'erasure_rate': 8.903855784902234},
#  {'_id': ObjectId('66e8140c8bad1c495d53e104'),
#   'interface_type': 'NVMe',
#   'model': 'PC601 NVMe SK hynix 256GB',
#   'serial_number': 'AD99N4523111Y9B11',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:26:44',
#   'elapsed_time_seconds': 1604,
#   'erasure_rate': 8.92050888175679},
#  {'_id': ObjectId('66e8140c8bad1c495d53ac60'),
#   'interface_type': 'NVMe',
#   'model': 'SK hynix PC601 HFS512GD9TNG-L2A0A',
#   'serial_number': 'AD9BN8886101YCB5D',
#   'raw_capacity': 512110190592,
#   'capacity_gb': 476.93978118896484,
#   'raw_elapsed_time': '00:39:22',
#   'elapsed_time_seconds': 2362,
#   'erasure_rate': 12.115320436637548},
#  {'_id': ObjectId('66e8140c8bad1c495d53ed2d'),
#   'interface_type': 'NVMe',
#   'model': 'PC601 NVMe SK hynix 512GB',
#   'serial_number': 'AJ97N451510907L0E',
#   'raw_capacity': 512110190592,
#   'capacity_gb': 476.93978118896484,
#   'raw_elapsed_time': '00:42:33',
#   'elapsed_time_seconds': 2553,
#   'erasure_rate': 11.208925527355227},
#  {'_id': ObjectId('66e8140c8bad1c495d53b3af'),
#   'interface_type': 'NVMe',
#   'model': 'PC601 NVMe SK hynix 512GB',
#   'serial_number': 'AJ97N451510907L0R',
#   'raw_capacity': 512110190592,
#   'capacity_gb': 476.93978118896484,
#   'raw_elapsed_time': '00:42:02',
#   'elapsed_time_seconds': 2522,
#   'erasure_rate': 11.346703755486873},
#  {'_id': ObjectId('66e8140c8bad1c495d53a67d'),
#   'interface_type': 'NVMe',
#   'model': 'SKHynix_HFS256GD9TNG-L5B0B',
#   'serial_number': 'AJ9AN43221020AA38',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:29:16',
#   'elapsed_time_seconds': 1756,
#   'erasure_rate': 8.148346381741396},
#  {'_id': ObjectId('66e8140c8bad1c495d53d5fc'),
#   'interface_type': 'NVMe',
#   'model': 'SKHynix_HFS256GD9TNG-L5B0B',
#   'serial_number': 'AJ9AN56231170AL2Y',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:27:56',
#   'elapsed_time_seconds': 1676,
#   'erasure_rate': 8.537288929795878},
#  {'_id': ObjectId('66e8140c8bad1c495d53dc2a'),
#   'interface_type': 'NVMe',
#   'model': 'SKHynix_HFS256GD9TNG-L5B0B',
#   'serial_number': 'AJ9BN87271020C34I',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:30:16',
#   'elapsed_time_seconds': 1816,
#   'erasure_rate': 7.879127888952583},
#  {'_id': ObjectId('66e8140c8bad1c495d53e07f'),
#   'interface_type': 'NVMe',
#   'model': 'SKHynix_HFS256GD9TNG-L5B0B',
#   'serial_number': 'AJ9BN87271120C30K',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:29:52',
#   'elapsed_time_seconds': 1792,
#   'erasure_rate': 7.9846519231796265},
#  {'_id': ObjectId('66e8140c8bad1c495d53b7dc'),
#   'interface_type': 'NVMe',
#   'model': 'SKHynix_HFS256GD9TNG-L5B0B',
#   'serial_number': 'AN9AN60021080AL4A',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:27:43',
#   'elapsed_time_seconds': 1663,
#   'erasure_rate': 8.604026606336676},
#  {'_id': ObjectId('66e8140c8bad1c495d53c070'),
#   'interface_type': 'NVMe',
#   'model': 'SKHynix_HFS256GD9TNG-L5B0B',
#   'serial_number': 'AN9AN60021110AV4F',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:29:57',
#   'elapsed_time_seconds': 1797,
#   'erasure_rate': 7.962435306810178},
#  {'_id': ObjectId('66e8140c8bad1c495d53d553'),
#   'interface_type': 'NVMe',
#   'model': 'SKHynix_HFS256GD9TNG-L5B0B',
#   'serial_number': 'AN9AN60021110AV4N',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:30:21',
#   'elapsed_time_seconds': 1821,
#   'erasure_rate': 7.8574938200647395},
#  {'_id': ObjectId('66e8140c8bad1c495d53c7a0'),
#   'interface_type': 'NVMe',
#   'model': 'SKHynix_HFS256GD9TNG-L5B0B',
#   'serial_number': 'AN9AN60021110AV4O',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:29:12',
#   'elapsed_time_seconds': 1752,
#   'erasure_rate': 8.166949912293317},
#  {'_id': ObjectId('66e8140c8bad1c495d53f33c'),
#   'interface_type': 'NVMe',
#   'model': 'SKHynix_HFS256GD9TNG-L5B0B',
#   'serial_number': 'AN9AN60021110AV4O',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:11:12',
#   'elapsed_time_seconds': 672,
#   'erasure_rate': 21.292405128479004},
#  {'_id': ObjectId('66e8140c8bad1c495d53c6a3'),
#   'interface_type': 'NVMe',
#   'model': 'BC511 NVMe SK hynix 256GB',
#   'serial_number': 'AS9CN51171390CB2O',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:37:36',
#   'elapsed_time_seconds': 2256,
#   'erasure_rate': 6.342418548908639},
#  {'_id': ObjectId('66e8140c8bad1c495d53af0e'),
#   'interface_type': 'NVMe',
#   'model': 'BC511 NVMe SK hynix 256GB',
#   'serial_number': 'AS9CN51171390CB2T',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:37:57',
#   'elapsed_time_seconds': 2277,
#   'erasure_rate': 6.283924570196701},
#  {'_id': ObjectId('66e8140c8bad1c495d53bdac'),
#   'interface_type': 'NVMe',
#   'model': 'BC511 NVMe SK hynix 256GB',
#   'serial_number': 'AS9CN51171390CB2U',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:34:57',
#   'elapsed_time_seconds': 2097,
#   'erasure_rate': 6.823317237166376},
#  {'_id': ObjectId('66e8140c8bad1c495d53dbc2'),
#   'interface_type': 'NVMe',
#   'model': 'BC511 NVMe SK hynix 256GB',
#   'serial_number': 'AS9CN51171390CB33',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:36:37',
#   'elapsed_time_seconds': 2197,
#   'erasure_rate': 6.512742943258029},
#  {'_id': ObjectId('66e8140c8bad1c495d53e020'),
#   'interface_type': 'NVMe',
#   'model': 'BC511 NVMe SK hynix 256GB',
#   'serial_number': 'AS9CN54631170CB52',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:35:56',
#   'elapsed_time_seconds': 2156,
#   'erasure_rate': 6.636593806279171},
#  {'_id': ObjectId('66e8140c8bad1c495d53b157'),
#   'interface_type': 'NVMe',
#   'model': 'BC511 NVMe SK hynix 256GB',
#   'serial_number': 'AS9CN54631170CB5Q',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:34:18',
#   'elapsed_time_seconds': 2058,
#   'erasure_rate': 6.952622082768655},
#  {'_id': ObjectId('66e8140c8bad1c495d53d8c0'),
#   'interface_type': 'NVMe',
#   'model': 'INTEL MEMPEK1J016GAH',
#   'serial_number': 'BTBT90420VPC016N',
#   'raw_capacity': 14403239936,
#   'capacity_gb': 13.4140625,
#   'raw_elapsed_time': '00:06:13',
#   'elapsed_time_seconds': 373,
#   'erasure_rate': 2.157758042895442},
#  {'_id': ObjectId('66e8140c8bad1c495d53d368'),
#   'interface_type': 'NVMe',
#   'model': 'INTEL SSDPEKKW256G8',
#   'serial_number': 'BTHH81951DPS256B',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:34:01',
#   'elapsed_time_seconds': 2041,
#   'erasure_rate': 7.010532212806414},
#  {'_id': ObjectId('66e8140c8bad1c495d53aa15'),
#   'interface_type': 'NVMe',
#   'model': 'SSDPEKKF256G8 NVMe INTEL 256GB',
#   'serial_number': 'BTHH82010X9W256B',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:34:59',
#   'elapsed_time_seconds': 2099,
#   'erasure_rate': 6.816815743848447},
#  {'_id': ObjectId('66e8140c8bad1c495d53bf84'),
#   'interface_type': 'NVMe',
#   'model': 'SSDPEKKF256G8 NVMe INTEL 256GB',
#   'serial_number': 'BTHH82020F90256B',
#   'raw_capacity': 256060514304,
#   'capacity_gb': 238.47493743896484,
#   'raw_elapsed_time': '00:37:27',
#   'elapsed_time_seconds': 2247,
#   'erasure_rate': 6.367822094498393},
#  ...]
