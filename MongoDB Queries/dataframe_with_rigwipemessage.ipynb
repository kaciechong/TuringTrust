# %%
import pandas as pd
# !pip install "pymongo[srv]"
import pymongo
from pymongo import MongoClient
# Out:
# Requirement already satisfied: pymongo[srv] in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (4.10.1)
# WARNING: pymongo 4.10.1 does not provide the extra 'srv'
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pymongo[srv]) (2.7.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Database access credentials: to establish a connection to the MongoDB server using the MongoClient.
# The connection string includes the username (user), password(123), and database details.
client = MongoClient("mongodb+srv://user:123@cluster0.9d0ja.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")

# Access the 'blancco' database
db = client["blancco"]

# Access the 'all_reports' collection within the 'blancco' database
all_reports_collection = db["all_reports"]

# Can now use 'all_reports_collection' to perform operations like find, insert, update, or aggregate data

# %%
pipeline = [
    { "$unwind": "$erasures" },

    # Match failed regular wipes with failure messages
    { 
        "$match": { 
            "erasures.state": "Failed", 
            "erasures.erase_messages.failure": { "$exists": True, "$ne": [] }, # failure messages exist
            "system": { "$ne": {} } # ensures it's a regular wipe (system field is not empty)
        }
    },

    # Add a field to mark this as regular wipe
    { 
        "$addFields": { "wipeType": "regular" }
    },

    # Group by serial number (disks which is same as erasure)
    { 
        "$group": {
            "_id": { "serial": "$disks.serial" }, 
            "failureMessages": { "$push": "$erasures.erase_messages.failure" } # Collect all failure messages
        }
    },

    # Lookup the rig wipe data based on serial number -- matching regular to rig
    {
        "$lookup": {
            "from": "all_reports", 
            "localField": "_id.serial", 
            "foreignField": "disks.serial", # Match the serial number in the rig wipe reports
            "as": "rigWipeData"
        }
    },

    # Unwind the rigWipeData array to process each device
    { "$unwind": "$rigWipeData" },

    # Match only rig wipe data where the system field is empty (indicating it's a rig wipe)
    {
        "$match": {
            "rigWipeData.system": { "$eq": {} }
        }
    },

    # Add a field for the rig wipe status (whether the wipe was successful or failed)
    {
        "$addFields": {
            "rigWipeStatus": { 
                "$ifNull": [
                    "$rigWipeData.erasures.state", # Extract the state of the rig wipe
                    "Unknown" # Default value if no state is found
                ] 
            },
            "rigWipeFailureMessages": {
                "$ifNull": [
                    "$rigWipeData.erasures.erase_messages", # Extract rig wipe failure messages
                    []
                ]
            }
        }
    },

    # Group by serial number, collecting failure messages and statuses
    {
        "$group": {
            "_id": "$_id.serial", # Group by serial number
            "failureMessages": { "$first": "$failureMessages" }, # Include failure messages from the regular wipe
            "rigWipeStatuses": { "$addToSet": "$rigWipeStatus" }, # Collect rig wipe statuses (Success/Failed)
            "rigWipeFailureMessages": { "$push": "$rigWipeFailureMessages" } # Collect rig wipe failure messages
        }
    },

    # Project the desired output
    {
        "$project": {
            "serial": "$_id",
            "failureMessages": 1, 
            "rigWipeStatuses": 1,
            "rigWipeFailureMessages": 1
        }
    }
]
result = all_reports_collection.aggregate(pipeline)
result_list = list(result)
df2 = pd.DataFrame(result_list)
df2 = df2.drop(columns=['_id'])
df2
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        failureMessages  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [[FORMAT NVMe (user data erase) command failed]]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [[ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [[FORMAT NVMe (user data erase) command failed]]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [[Cryptographic erasure has failed, Shadow MBR area content was not erased by the user]]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                          [[Previously written pattern found, Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification]]
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [[Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification]]
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification, Self-test completed with read failure.]]
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [[Cryptographic erasure has failed]]
# 8                                                                                                                                                                                                                                                                                                                                                                                              [[Erasure target is offline., Write errors count reaches or exceeds the configured threshold, sector(s) failed to overwrite, Remapped sectors area was not erased by the user, Self-test aborted by internal timeout.]]
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [[Erasure target is offline.]]
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [[Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification]]
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]]
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [[FORMAT NVMe (crypto erase) command failed]]
# 13                                                                                                                                                                                                                                                                                                                                                                                                 [[Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification, Remapped sectors area was not erased by the user, Self-test completed with read failure.]]
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]]
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [[FORMAT NVMe (crypto erase) command failed]]
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]]
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[Erasure target is offline., Self-test fatal error or unknown test error occurred.]]
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]]
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]]
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [[ENHANCED SECURE ERASE command failed, SECURE ERASE command failed], [ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]]
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [[FORMAT NVMe (crypto erase) command failed]]
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[FORMAT NVMe (user data erase) command failed]]
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [[Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification]]
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[FORMAT NVMe (user data erase) command failed]]
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [[Erasure target is offline., Remapped sectors area was not erased by the user, Self-test completed with unknown failure.]]
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [[BLOCK ERASE EXT command failed]]
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[FORMAT NVMe (user data erase) command failed]]
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[DCO area was not removed by the user, DCO area content was not erased by the user]]
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [[Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification]]
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [[FORMAT NVMe (crypto erase) command failed]]
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [[Verification failed, sector(s) failed the verification]]
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[FORMAT NVMe (user data erase) command failed]]
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[FORMAT NVMe (user data erase) command failed]]
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [[Erasure target is offline.], [Erasure target is offline.]]
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [[BLOCK ERASE EXT command failed]]
# 36                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [[FORMAT NVMe (crypto erase) command failed]]
# 37                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [[Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification]]
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[FORMAT NVMe (user data erase) command failed]]
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [[FORMAT NVMe (crypto erase) command failed]]
# 40                                                                                                                                                                                                                                                                                                                                                                                                                                                   [[Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification, Self-test completed with read failure.]]
# 41                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[Erasure target is offline., Remapped sectors area was not erased by the user]]
# 42                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [[FORMAT NVMe (crypto erase) command failed]]
# 43                                                                                                                                                                                                                                                                                                                                                                                                                                                         [[Previously written pattern found, Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification]]
# 44                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [[Cryptographic erasure has failed, Shadow MBR area content was not erased by the user]]
# 45                                                                                                                                                                                                                                                                                                                                                                                                       [[Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification, Self-test completed with failure and drive is suspected of having handling damage.]]
# 46                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[FORMAT NVMe (user data erase) command failed]]
# 47                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[FORMAT NVMe (user data erase) command failed]]
# 48                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [[Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification]]
# 49                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [[BLOCK ERASE EXT command failed]]
# 50                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [[BLOCK ERASE EXT command failed]]
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                         [[Previously written pattern found, Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification]]
# 52                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [[Cryptographic erasure has failed, Shadow MBR area content was not erased by the user]]
# 53                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]]
# 54                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[FORMAT NVMe (user data erase) command failed]]
# 55                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]]
# 56                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]]
# 57                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [[BLOCK ERASE EXT command failed]]
# 58                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [[Erasure target is offline.]]
# 59                                                                                                                                                                                                                                                                                                                                                                                                                                                         [[Previously written pattern found, Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification]]
# 60                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [[BLOCK ERASE EXT command failed]]
# 61                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [[Verification failed, sector(s) failed the verification]]
# 62                                                                                                                                                                                                                                                                                                                                                                                             [[Erasure target is offline., ENHANCED SECURE ERASE command failed, Erasure target is offline., SECURE ERASE command failed, Remapped sectors area was not erased by the user, Self-test completed with read failure.]]
# 63                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]]
# 64                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [[Capacity of erasure target has changed., DCO area was not removed by the user, DCO area content was not erased by the user]]
# 65                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]]
# 66                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [[Cryptographic erasure has failed, Remapped sectors area was not erased by the user, Shadow MBR area content was not erased by the user]]
# 67                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [[Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification]]
# 68                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [[Cryptographic erasure has failed]]
# 69                                                                                                                                                                                                                                                                                                                                                                                                                                                [[Erasure target is offline., Remapped sectors area was not erased by the user, Self-test completed with failure and drive is suspected of having handling damage.]]
# 70                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [[Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification]]
# 71                                                                                                                                                                                                                                                                                                                                                                                            [[Cryptographic erasure has failed, Shadow MBR area content was not erased by the user], [Cryptographic erasure has failed, Shadow MBR area content was not erased by the user, Self-test aborted by internal timeout.]]
# 72                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [[Cryptographic erasure has failed, Shadow MBR area content was not erased by the user]]
# 73                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [[FORMAT NVMe (crypto erase) command failed]]
# 74                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [[Cryptographic erasure has failed, Shadow MBR area content was not erased by the user]]
# 75                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]]
# 76                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[FORMAT NVMe (user data erase) command failed]]
# 77                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]]
# ...
# 261                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [[{'information': ['Exceeds NIST-Clear', 'Self-test completed without error.'], 'failure': [], 'exception': ['Device is SSD, see manual for more information']}]]
# 262                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [[{'information': [], 'failure': [], 'exception': ['Remapped sectors area was not erased by the user', 'Self-test completed with unknown failure.']}]]
#
#                                       serial
# 0                           [S443NX0M247743]
# 1                     [TW05MFP0550855780009]
# 2                           [S364NA0J936916]
# 3                             [174619ACAE68]
# 4                             [2I4920053065]
# 5                       [FBFB180605C0003667]
# 6                          [WD-WCC3F0CTU036]
# 7                             [39IS1128TMFQ]
# 8                                [83KZ0ZHKS]
# 9                   [Z9AYS9T8, 1844E1D4C3F6]
# 10                         [WD-WCC2EUE08031]
# 11                          [S4HENX0N914164]
# 12                          [S35ENX2K601861]
# 13                         [WD-WCC2EKVNZNCV]
# 14                            [141341400510]
# 15                          [S35ENX1K710588]
# 16                          [S4HENX0N914216]
# 17                       [EI76N028710106G09]
# 18                            [153795400018]
# 19                            [141342401722]
# 20                        [50026B76832EC2A1]
# 21                          [S35ENX1K626373]
# 22                          [S29PNXAGB08254]
# 23                          [S1X7J9GB401190]
# 24                       [FJ84N78771150564C]
# 25                                [S2WRY0LE]
# 26                          [S4YCNF0NA16761]
# 27                          [S364NX0K213793]
# 28                                [6VPGKT1L]
# 29                         [WD-WMC2E0H64YZA]
# 30                          [S35ENX0K235792]
# 31                         [WD-WMAV2DS77603]
# 32                          [S364NX0J321844]
# 33                       [ES84N714711704S55]
# 34                            [2K452LASQ6NT]
# 35                          [S50ANF1NC52422]
# 36                          [S35ENX1JA63310]
# 37                         [WD-WCC3F0CTURR2]
# 38                    [TW0XVRV7LOH006CG003D]
# 39                          [S35ENX1K710829]
# 40                         [WD-WCC1S1787675]
# 41                                [Z6EANBFS]
# 42                          [S35ENX0J210434]
# 43                            [2I4920062378]
# 44                            [164614AF872F]
# 45                          [S20BJ90D110232]
# 46                          [S364NX0JC11026]
# 47                          [S29NNXAH389203]
# 48                         [WD-WXG1EB0CRC24]
# 49                          [S4UKNE0MA63233]
# 50                          [S50ANF1NC52913]
# 51                            [2I4920053085]
# 52                            [14050966D119]
# 53                              [B828712486]
# 54                          [S29PNXAGB08235]
# 55                            [141341406377]
# 56                            [142921414724]
# 57                          [S50ANF1NC52839]
# 58                         [WD-WMARW1121483]
# 59                            [2I4920064179]
# 60                          [S4UKNE0MA64196]
# 61                         [WD-WCC2EMX2TK9K]
# 62                [W0Q5TEKN, S0TYNEACC34013]
# 63                            [142478402605]
# 64                         [WD-WCC2ER294117]
# 65                              [B828712459]
# 66                            [14050966D130]
# 67           [14310E19E079, WD-WCC3F1YLYAD5]
# 68                       [AN9AN60021110AV4F]
# 69                       [EJ78N447311008656]
# 70                         [WD-WMC2E0D32SF2]
# 71                            [14100C0693F8]
# 72                            [1913E1F670FB]
# 73                          [S35ENX0J758725]
# 74                            [174719C89A32]
# 75                            [142366401221]
# 76                          [S443NX0M248654]
# 77                            [153795400204]
# 78                          [JP1572FN2ZZ50K]
# 79           [14230E19EF60, WD-WCC3F5DAK3FN]
# 80                                [S2WRY1ZL]
# 81                                [W762TQ1D]
# 82                          [S35ENA1K218696]
# 83                         [WD-WXN0A99M8846]
# 84                       [MS89N67681050AI4C]
# 85                          [S2YGJ9BDB00378]
# 86                          [S29NNXAH310493]
# 87                          [S35ENX1J639355]
# 88                        [50026B76832EE4C0]
# 89                         [WD-WCC6Z2PZJ5J6]
# 90                        [50026B7779038D08]
# 91                          [S443NX0M247605]
# 92                        [CVLY628500ZW240D]
# 93                          [S35ENA1K218765]
# 94                          [S0NCNEAB204797]
# 95                            [172025800048]
# 96                                [6VPGKQSB]
# 97                            [1926BA803236]
# 98                            [17OB604FKLGU]
# 99                        [50026B724504B112]
# 100                   [1512811100010247096D]
# 101                        [WD-WMC2E0H0THFZ]
# 102                      [FJ84N78771180563N]
# 103                         [S29PNXAGB08246]
# 104                           [19518B807850]
# 105                         [S29NNXAH334836]
# 106                        [WD-WXP1A68K10T2]
# 107                         [S29PNXAGB08240]
# 108                      [MN92N06531180283C]
# 109                       [50026B7777056B4E]
# 110                         [TF0400Y13DUXWT]
# 111                        [WD-WCC3FL06Z8UX]
# 112                      [FJ84N787711805645]
# 113                           [2J2920174536]
# 114                           [141597401579]
# 115                         [S4HENX0N914220]
# 116                       [50026B723A07A700]
# 117  [125079080000149201B1, WD-WCATRA646662]
# 118                         [S4HENX0N915302]
# 119                         [S364NX0J321843]
# 120                   [TW00RNVG550853282794]
# 121                      [AJ9BN87271020C34I]
# 122          [14310E19E048, WD-WCC3F4RXXXYN]
# 123                 [ZN14LV4R, 1915E1FABDE0]
# 124                           [2I3220012770]
# 125                         [S364NX0JC11065]
# 126                           [121439301694]
# 127                           [142331405311]
# 128                         [S4HENX0N913956]
# 129                           [14090C054E16]
# 130                         [S509NF0N412106]
# 131                           [1951AR446119]
# 132                               [5VPBT6WC]
# 133                   [100720PBPB04ECHXK99F]
# 134                               [5VD7V8TD]
# 135                           [1821E13F2047]
# 136                        [WD-WX51A35453FU]
# 137                           [2J2920178398]
# 138                           [2J2920175467]
# 139                           [2I4920063403]
# 140                         [S29NNXAH334897]
# 141                               [6VMCTS4J]
# 142      [EI54N023010604721, S11DNYAD904713]
# 143                         [S4HENX0N913672]
# 144                 [Z9AYSHJ3, 1844E1D4C421]
# 145                         [S35ENX1K626412]
# 146                         [S364NA0J936948]
# 147                         [S35ENA1K218828]
# 148              [S2RBNX0J327904H, Z4Y1K4TD]
# 149                      [MJ8AN47581050A82F]
# 150                        [WD-WCC3F6ZTZHT5]
# 151                           [174719C8763B]
# 152                         [S443NF0K628684]
# 153                         [S35ENX1K116429]
# 154                             [B828712403]
# 155                         [S35ENX0K421928]
# 156                         [S35ENX1K710809]
# 157                         [S50ANF0N648309]
# 158                           [2048E4D3E55A]
# 159                         [S35ENX1K666313]
# 160         [W1E3WJXA, TW0XFJWX5508534J5943]
# 161                         [S0NCNEAB300635]
# 162                         [S35ENA1K218754]
# 163                [31QIT27HT, 174020806082]
# 164                         [S3TNNF0K669924]
# 165                         [S35ENX1K710677]
# 166                        [WD-WCC2ENNAT5V2]
# 167                   [TW0XVRV7LOH006CG00JW]
# 168                           [174020802932]
# 169                           [18021A6C9650]
# 170                           [171801803620]
# 171                         [S364NX0J321857]
# 172          [14230E19F9D9, WD-WCC3F5DAKT6F]
# 173                        [WD-WCC2EN8ZU22Z]
# 174                           [2024E2AABA8C]
# 175                         [S359NB0J446014]
# 176                         [S35ENX0K421571]
# 177                           [2J2920174500]
# 178                           [18021A88E733]
# 179                 [17501A17EA9A, Z9AQP7ET]
# 180                           [141597403493]
# 181                      [EJ85N40381CB9580D]
# 182                                       []
# 183                         [S35ENX0K422502]
# 184                              [7491C8K3T]
# 185                           [142366403382]
# 186                           [14090C054DA9]
# 187                         [S35ENX0K756715]
# 188                           [141597405056]
# 189                         [S364NX0J321897]
# 190                         [S50ANF0N648261]
# 191                               [Z6ECETW8]
# 192                         [S443NA0K945285]
# 193          [170615BA364E, WD-WCC6Y4CVHUFT]
# 194                      [FJ64N503611404K4T]
# 195                        [WD-WCC6Z2FS8KX3]
# 196                         [S50ANF1N364088]
# 197                         [S35ENX1K710666]
# 198                           [141597404700]
# 199                           [171801804014]
# 200                               [S2WRMTGQ]
# 201                           [192045801643]
# 202                      [AJ9BN87271120C30K]
# 203                        [WD-WMAV2FR98061]
# 204                           [2J2920179059]
# 205          [WD-WCC6Y6UF7CCL, 1849E1DC22B8]
# 206                      [FJ84N787712605528]
# 207                           [174719C8386B]
# 208                   [TW0V89JT5508567TB26N]
# 209                         [S35ENX0J108233]
# 210          [14310E19DA44, WD-WCC3F4TAE2E8]
# 211                         [S35ENX0J637184]
# 212          [14230E1A2283, WD-WCC3F2SK3937]
# 213                         [S35ENX1K710670]
# 214                         [S364NX0JC11070]
# 215                               [S2WPD4FM]
# 216                               [W624Z98K]
# 217                         [S364NX0J321832]
# 218                         [S35ENX0K652023]
# 219                   [TW0XFJWX5508534J5943]
# 220                 [Z9AYS9GL, 1844E1D4C3F4]
# 221                   [TW0XRV8D550854535272]
# 222                           [142367401579]
# 223                      [AN9AN60021110AV4N]
# 224                         [S35ENX0K501640]
# 225                               [5VD23JJK]
# 226                               [S2WRMVCC]
# 227                         [S50ANF0NC09055]
# 228                       [50026B777805D366]
# 229                         [S50ANF0N647600]
# 230                           [17OB6063KLGU]
# 231                         [S35ENX0K334537]
# 232                         [S35ENA1J993678]
# 233                        [WD-WCC2EC7KAKYU]
# 234                   [TW0V89JT5508567TB3QT]
# 235                         [S443NE0M544126]
# 236                               [5RG1MG0G]
# 237                         [S364NX0J321902]
# 238                              [601BTEMFT]
# 239                           [1851A8804499]
# 240                      [ES84N731710204R2Q]
# 241                         [S443NA0K945488]
# 242                        [WD-WCC2EF7T8671]
# 243          [14310E19E04B, WD-WCC3F5DAKFZ8]
# 244                         [S29NNXAGB29868]
# 245                         [UKCVC01ZTEPEBW]
# 246                        [WD-WMC2E0N2SYJJ]
# 247                      [AN9AN60021110AV4O]
# 248                   [01D3075C0C3700159398]
# 249                           [18021A6CC1B6]
# 250                              [582KCAPST]
# 251                         [S50ANF1NC54429]
# 252                         [S50ANF0N647647]
# 253                         [S364NX0J321644]
# 254                         [S364NX0JC05759]
# 255                         [S359NB0J609878]
# 256          [170615BA3677, WD-WCC3F7YCTS86]
# 257                         [S29NNXAH334901]
# 258                         [S50ANF0N929676]
# 259                         [S4HENX0N914182]
# 260                         [S443NX0M247022]
# 261                           [144307400495]
# 262                               [W620WK61]

# %%
def keep_successful(status_list):
    if isinstance(status_list, list):
        # Flatten any nested lists if necessary
        flat_list = [item for sublist in status_list for item in sublist] if any(isinstance(i, list) for i in status_list) else status_list
        # Return "Successful" if it exists, otherwise the first status (or None)
        return ["Successful"] if "Successful" in flat_list else [flat_list[0]] if flat_list else []
    return status_list
df2["rigWipeStatuses"] = df2["rigWipeStatuses"].apply(keep_successful)


def keep_latest(serial_list):
    if isinstance(serial_list, list) and len(serial_list) > 0:
        return [serial_list[-1]]  # Keep only the last item
    return serial_list  # Return as is if not a list or empty
df2["serial"] = df2["serial"].apply(keep_latest)

for column in ['failureMessages', 'rigWipeStatuses', 'serial']:
    # Flatten nested lists if they contain only one item
    df2[column] = df2[column].apply(lambda x: x[0] if isinstance(x, list) and len(x) == 1 else x)
    
    # Make sure we are NOT splitting failureMessages or other fields by commas
    # Explode only if the column is already a list
    if df2[column].apply(lambda x: isinstance(x, list)).any():
        df2 = df2.explode(column)

# %%
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)  # Do not truncate output horizontally
pd.set_option('display.max_colwidth', None)  # Show full column content without truncation

df2
# Out:
#                                                                                                                                                                                                        failureMessages  \
# 0                                                                                                                                                                         FORMAT NVMe (user data erase) command failed
# 1                                                                                                                                                                                 ENHANCED SECURE ERASE command failed
# 1                                                                                                                                                                                          SECURE ERASE command failed
# 2                                                                                                                                                                         FORMAT NVMe (user data erase) command failed
# 3                                                                                                                                                                                     Cryptographic erasure has failed
# 3                                                                                                                                                                   Shadow MBR area content was not erased by the user
# 4                                                                                                                                                                                     Previously written pattern found
# 4                                                                                                                                                                                                  Verification failed
# 4                                                                                                                                                        Read errors count reaches or exceeds the configured threshold
# 4                                                                                                                                                                                    sector(s) failed the verification
# 5                                                                                                                                                                                                  Verification failed
# 5                                                                                                                                                        Read errors count reaches or exceeds the configured threshold
# 5                                                                                                                                                                                    sector(s) failed the verification
# 6                                                                                                                                                                                                  Verification failed
# 6                                                                                                                                                        Read errors count reaches or exceeds the configured threshold
# 6                                                                                                                                                                                    sector(s) failed the verification
# 6                                                                                                                                                                               Self-test completed with read failure.
# 7                                                                                                                                                                                     Cryptographic erasure has failed
# 8                                                                                                                                                                                           Erasure target is offline.
# 8                                                                                                                                                       Write errors count reaches or exceeds the configured threshold
# 8                                                                                                                                                                                        sector(s) failed to overwrite
# 8                                                                                                                                                                     Remapped sectors area was not erased by the user
# 8                                                                                                                                                                               Self-test aborted by internal timeout.
# 9                                                                                                                                                                                           Erasure target is offline.
# 10                                                                                                                                                                                                 Verification failed
# 10                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 10                                                                                                                                                                                   sector(s) failed the verification
# 11                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 11                                                                                                                                                                                         SECURE ERASE command failed
# 12                                                                                                                                                                           FORMAT NVMe (crypto erase) command failed
# 13                                                                                                                                                                                                 Verification failed
# 13                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 13                                                                                                                                                                                   sector(s) failed the verification
# 13                                                                                                                                                                    Remapped sectors area was not erased by the user
# 13                                                                                                                                                                              Self-test completed with read failure.
# 14                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 14                                                                                                                                                                                         SECURE ERASE command failed
# 15                                                                                                                                                                           FORMAT NVMe (crypto erase) command failed
# 16                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 16                                                                                                                                                                                         SECURE ERASE command failed
# 17                                                                                                                                                                                          Erasure target is offline.
# 17                                                                                                                                                               Self-test fatal error or unknown test error occurred.
# 18                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 18                                                                                                                                                                                         SECURE ERASE command failed
# 19                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 19                                                                                                                                                                                         SECURE ERASE command failed
# 20                                                                                                                                                 [ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]
# 20                                                                                                                                                 [ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]
# 21                                                                                                                                                                           FORMAT NVMe (crypto erase) command failed
# 22                                                                                                                                                                        FORMAT NVMe (user data erase) command failed
# 23                                                                                                                                                                                                 Verification failed
# 23                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 23                                                                                                                                                                                   sector(s) failed the verification
# 24                                                                                                                                                                        FORMAT NVMe (user data erase) command failed
# 25                                                                                                                                                                                          Erasure target is offline.
# 25                                                                                                                                                                    Remapped sectors area was not erased by the user
# 25                                                                                                                                                                           Self-test completed with unknown failure.
# 26                                                                                                                                                                                      BLOCK ERASE EXT command failed
# 27                                                                                                                                                                        FORMAT NVMe (user data erase) command failed
# 28                                                                                                                                                                                DCO area was not removed by the user
# 28                                                                                                                                                                         DCO area content was not erased by the user
# 29                                                                                                                                                                                                 Verification failed
# 29                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 29                                                                                                                                                                                   sector(s) failed the verification
# 30                                                                                                                                                                           FORMAT NVMe (crypto erase) command failed
# 31                                                                                                                                                                                                 Verification failed
# 31                                                                                                                                                                                   sector(s) failed the verification
# 32                                                                                                                                                                        FORMAT NVMe (user data erase) command failed
# 33                                                                                                                                                                        FORMAT NVMe (user data erase) command failed
# 34                                                                                                                                                                                        [Erasure target is offline.]
# 34                                                                                                                                                                                        [Erasure target is offline.]
# 35                                                                                                                                                                                      BLOCK ERASE EXT command failed
# 36                                                                                                                                                                           FORMAT NVMe (crypto erase) command failed
# 37                                                                                                                                                                                                 Verification failed
# 37                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 37                                                                                                                                                                                   sector(s) failed the verification
# 38                                                                                                                                                                        FORMAT NVMe (user data erase) command failed
# 39                                                                                                                                                                           FORMAT NVMe (crypto erase) command failed
# 40                                                                                                                                                                                                 Verification failed
# 40                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 40                                                                                                                                                                                   sector(s) failed the verification
# 40                                                                                                                                                                              Self-test completed with read failure.
# 41                                                                                                                                                                                          Erasure target is offline.
# 41                                                                                                                                                                    Remapped sectors area was not erased by the user
# 42                                                                                                                                                                           FORMAT NVMe (crypto erase) command failed
# 43                                                                                                                                                                                    Previously written pattern found
# 43                                                                                                                                                                                                 Verification failed
# 43                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 43                                                                                                                                                                                   sector(s) failed the verification
# 44                                                                                                                                                                                    Cryptographic erasure has failed
# 44                                                                                                                                                                  Shadow MBR area content was not erased by the user
# 45                                                                                                                                                                                                 Verification failed
# 45                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 45                                                                                                                                                                                   sector(s) failed the verification
# 45                                                                                                                                  Self-test completed with failure and drive is suspected of having handling damage.
# 46                                                                                                                                                                        FORMAT NVMe (user data erase) command failed
# 47                                                                                                                                                                        FORMAT NVMe (user data erase) command failed
# 48                                                                                                                                                                                                 Verification failed
# 48                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 48                                                                                                                                                                                   sector(s) failed the verification
# 49                                                                                                                                                                                      BLOCK ERASE EXT command failed
# 50                                                                                                                                                                                      BLOCK ERASE EXT command failed
# 51                                                                                                                                                                                    Previously written pattern found
# 51                                                                                                                                                                                                 Verification failed
# 51                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 51                                                                                                                                                                                   sector(s) failed the verification
# 52                                                                                                                                                                                    Cryptographic erasure has failed
# 52                                                                                                                                                                  Shadow MBR area content was not erased by the user
# 53                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 53                                                                                                                                                                                         SECURE ERASE command failed
# 54                                                                                                                                                                        FORMAT NVMe (user data erase) command failed
# 55                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 55                                                                                                                                                                                         SECURE ERASE command failed
# 56                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 56                                                                                                                                                                                         SECURE ERASE command failed
# 57                                                                                                                                                                                      BLOCK ERASE EXT command failed
# 58                                                                                                                                                                                          Erasure target is offline.
# 59                                                                                                                                                                                    Previously written pattern found
# 59                                                                                                                                                                                                 Verification failed
# 59                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 59                                                                                                                                                                                   sector(s) failed the verification
# 60                                                                                                                                                                                      BLOCK ERASE EXT command failed
# 61                                                                                                                                                                                                 Verification failed
# 61                                                                                                                                                                                   sector(s) failed the verification
# 62                                                                                                                                                                                          Erasure target is offline.
# 62                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 62                                                                                                                                                                                          Erasure target is offline.
# 62                                                                                                                                                                                         SECURE ERASE command failed
# 62                                                                                                                                                                    Remapped sectors area was not erased by the user
# 62                                                                                                                                                                              Self-test completed with read failure.
# 63                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 63                                                                                                                                                                                         SECURE ERASE command failed
# 64                                                                                                                                                                             Capacity of erasure target has changed.
# 64                                                                                                                                                                                DCO area was not removed by the user
# 64                                                                                                                                                                         DCO area content was not erased by the user
# 65                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 65                                                                                                                                                                                         SECURE ERASE command failed
# 66                                                                                                                                                                                    Cryptographic erasure has failed
# 66                                                                                                                                                                    Remapped sectors area was not erased by the user
# 66                                                                                                                                                                  Shadow MBR area content was not erased by the user
# 67                                                                                                                                                                                                 Verification failed
# 67                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 67                                                                                                                                                                                   sector(s) failed the verification
# 68                                                                                                                                                                                    Cryptographic erasure has failed
# 69                                                                                                                                                                                          Erasure target is offline.
# 69                                                                                                                                                                    Remapped sectors area was not erased by the user
# 69                                                                                                                                  Self-test completed with failure and drive is suspected of having handling damage.
# 70                                                                                                                                                                                                 Verification failed
# 70                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 70                                                                                                                                                                                   sector(s) failed the verification
# 71                                                                                                                              [Cryptographic erasure has failed, Shadow MBR area content was not erased by the user]
# 71                                                                                      [Cryptographic erasure has failed, Shadow MBR area content was not erased by the user, Self-test aborted by internal timeout.]
# 72                                                                                                                                                                                    Cryptographic erasure has failed
# 72                                                                                                                                                                  Shadow MBR area content was not erased by the user
# 73                                                                                                                                                                           FORMAT NVMe (crypto erase) command failed
# 74                                                                                                                                                                                    Cryptographic erasure has failed
# 74                                                                                                                                                                  Shadow MBR area content was not erased by the user
# 75                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 75                                                                                                                                                                                         SECURE ERASE command failed
# 76                                                                                                                                                                        FORMAT NVMe (user data erase) command failed
# 77                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 77                                                                                                                                                                                         SECURE ERASE command failed
# 78                                                                                                                                                                             Capacity of erasure target has changed.
# 78                                                                                                                                                                                DCO area was not removed by the user
# 78                                                                                                                                                                         DCO area content was not erased by the user
# 79                                                                                                                                                                                                 Verification failed
# 79                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 79                                                                                                                                                                                   sector(s) failed the verification
# 79                                                                                                                                                                                DCO area was not removed by the user
# 79                                                                                                                                                                         DCO area content was not erased by the user
# 80                                                                                                                                                                                                 Verification failed
# 80                                                                                                                                                                                   sector(s) failed the verification
# 81                                                                                                                                                                                          Erasure target is offline.
# 81                                                                                                                                                                                                 Verification failed
# 81                                                                                                                                                                                   sector(s) failed the verification
# 81                                                                                                                                                                    Remapped sectors area was not erased by the user
# 81                                                                                                                                                  Device detected as a Hybrid drive, see manual for more information
# 81                                                                                                                                                                              Self-test completed with read failure.
# 82                                                                                                                                                                           FORMAT NVMe (crypto erase) command failed
# 83                                                     [Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification, Self-test completed with read failure.]
# 83                                                                                             [Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification]
# 84                                                                                                                     [Write errors count reaches or exceeds the configured threshold, sector(s) failed to overwrite]
# 84                                                                                                                     [Write errors count reaches or exceeds the configured threshold, sector(s) failed to overwrite]
# 85                                                                                                                                                                                                 Verification failed
# 85                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 85                                                                                                                                                                                   sector(s) failed the verification
# 85                                                                                                                                                                              Self-test completed with read failure.
# 86                                                                                                                                                                        FORMAT NVMe (user data erase) command failed
# 87                                                                                                                                                                           FORMAT NVMe (crypto erase) command failed
# 88                                                                                                                                                 [ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]
# 88                                                                                                                                                 [ENHANCED SECURE ERASE command failed, SECURE ERASE command failed]
# 89                                                                                                                                                                                                 Verification failed
# 89                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 89                                                                                                                                                                                   sector(s) failed the verification
# 89                                                                                                                                                                              Self-test completed with read failure.
# 90                                                                                                                                                                                          Erasure target is offline.
# 91                                                                                                                                                                        FORMAT NVMe (user data erase) command failed
# 92                                                                                                                                                      Write errors count reaches or exceeds the configured threshold
# 92                                                                                                                                                                                       sector(s) failed to overwrite
# 92                                                                                                                                                                    Remapped sectors area was not erased by the user
# 92                                                                                                                                                                              Self-test completed with read failure.
# 93                                                                                                                                                                           FORMAT NVMe (crypto erase) command failed
# 94                                               [Write errors count reaches or exceeds the configured threshold, sector(s) failed to overwrite, Remapped sectors area was not erased by the user, Self-test timeout.]
# 94                           [Write errors count reaches or exceeds the configured threshold, sector(s) failed to overwrite, Remapped sectors area was not erased by the user, Self-test completed with read failure.]
# 95                                                                                                                                                                                          Erasure target is offline.
# 95                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 95                                                                                                                                                                                          Erasure target is offline.
# 95                                                                                                                                                                                         SECURE ERASE command failed
# 96                                                                                                                                                                                                 Verification failed
# 96                                                                                                                                                       Read errors count reaches or exceeds the configured threshold
# 96                                                                                                                                                                                   sector(s) failed the verification
# 96                                                                                                                                                                              Self-test completed with read failure.
# 97                                                                                                                                                                        FORMAT NVMe (user data erase) command failed
# 98                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 98                                                                                                                                                                                         SECURE ERASE command failed
# 98                                                                                                                                                                    Remapped sectors area was not erased by the user
# 99                                                                                                                                                                                ENHANCED SECURE ERASE command failed
# 99                                                                                                                                                                                         SECURE ERASE command failed
# 100                                                          [Previously written pattern found, Verification failed, Read errors count reaches or exceeds the configured threshold, sector(s) failed the verification]
# ...
# 6         WD-WCC3F0CTU036
# 7            39IS1128TMFQ
# 8               83KZ0ZHKS
# 8               83KZ0ZHKS
# 8               83KZ0ZHKS
# 8               83KZ0ZHKS
# 8               83KZ0ZHKS
# 9            1844E1D4C3F6
# 10        WD-WCC2EUE08031
# 10        WD-WCC2EUE08031
# 10        WD-WCC2EUE08031
# 11         S4HENX0N914164
# 11         S4HENX0N914164
# 12         S35ENX2K601861
# 13        WD-WCC2EKVNZNCV
# 13        WD-WCC2EKVNZNCV
# 13        WD-WCC2EKVNZNCV
# 13        WD-WCC2EKVNZNCV
# 13        WD-WCC2EKVNZNCV
# 14           141341400510
# 14           141341400510
# 15         S35ENX1K710588
# 16         S4HENX0N914216
# 16         S4HENX0N914216
# 17      EI76N028710106G09
# 17      EI76N028710106G09
# 18           153795400018
# 18           153795400018
# 19           141342401722
# 19           141342401722
# 20       50026B76832EC2A1
# 20       50026B76832EC2A1
# 21         S35ENX1K626373
# 22         S29PNXAGB08254
# 23         S1X7J9GB401190
# 23         S1X7J9GB401190
# 23         S1X7J9GB401190
# 24      FJ84N78771150564C
# 25               S2WRY0LE
# 25               S2WRY0LE
# 25               S2WRY0LE
# 26         S4YCNF0NA16761
# 27         S364NX0K213793
# 28               6VPGKT1L
# 28               6VPGKT1L
# 29        WD-WMC2E0H64YZA
# 29        WD-WMC2E0H64YZA
# 29        WD-WMC2E0H64YZA
# 30         S35ENX0K235792
# 31        WD-WMAV2DS77603
# 31        WD-WMAV2DS77603
# 32         S364NX0J321844
# 33      ES84N714711704S55
# 34           2K452LASQ6NT
# 34           2K452LASQ6NT
# 35         S50ANF1NC52422
# 36         S35ENX1JA63310
# 37        WD-WCC3F0CTURR2
# 37        WD-WCC3F0CTURR2
# 37        WD-WCC3F0CTURR2
# 38   TW0XVRV7LOH006CG003D
# 39         S35ENX1K710829
# 40        WD-WCC1S1787675
# 40        WD-WCC1S1787675
# 40        WD-WCC1S1787675
# 40        WD-WCC1S1787675
# 41               Z6EANBFS
# 41               Z6EANBFS
# 42         S35ENX0J210434
# 43           2I4920062378
# 43           2I4920062378
# 43           2I4920062378
# 43           2I4920062378
# 44           164614AF872F
# 44           164614AF872F
# 45         S20BJ90D110232
# 45         S20BJ90D110232
# 45         S20BJ90D110232
# 45         S20BJ90D110232
# 46         S364NX0JC11026
# 47         S29NNXAH389203
# 48        WD-WXG1EB0CRC24
# 48        WD-WXG1EB0CRC24
# 48        WD-WXG1EB0CRC24
# 49         S4UKNE0MA63233
# 50         S50ANF1NC52913
# 51           2I4920053085
# 51           2I4920053085
# 51           2I4920053085
# 51           2I4920053085
# 52           14050966D119
# 52           14050966D119
# 53             B828712486
# 53             B828712486
# 54         S29PNXAGB08235
# 55           141341406377
# 55           141341406377
# 56           142921414724
# 56           142921414724
# 57         S50ANF1NC52839
# 58        WD-WMARW1121483
# 59           2I4920064179
# 59           2I4920064179
# 59           2I4920064179
# 59           2I4920064179
# 60         S4UKNE0MA64196
# 61        WD-WCC2EMX2TK9K
# 61        WD-WCC2EMX2TK9K
# 62         S0TYNEACC34013
# 62         S0TYNEACC34013
# 62         S0TYNEACC34013
# 62         S0TYNEACC34013
# 62         S0TYNEACC34013
# 62         S0TYNEACC34013
# 63           142478402605
# 63           142478402605
# 64        WD-WCC2ER294117
# 64        WD-WCC2ER294117
# 64        WD-WCC2ER294117
# 65             B828712459
# 65             B828712459
# 66           14050966D130
# 66           14050966D130
# 66           14050966D130
# 67        WD-WCC3F1YLYAD5
# 67        WD-WCC3F1YLYAD5
# 67        WD-WCC3F1YLYAD5
# 68      AN9AN60021110AV4F
# 69      EJ78N447311008656
# 69      EJ78N447311008656
# 69      EJ78N447311008656
# 70        WD-WMC2E0D32SF2
# 70        WD-WMC2E0D32SF2
# 70        WD-WMC2E0D32SF2
# 71           14100C0693F8
# 71           14100C0693F8
# 72           1913E1F670FB
# 72           1913E1F670FB
# 73         S35ENX0J758725
# 74           174719C89A32
# 74           174719C89A32
# 75           142366401221
# 75           142366401221
# 76         S443NX0M248654
# 77           153795400204
# 77           153795400204
# 78         JP1572FN2ZZ50K
# 78         JP1572FN2ZZ50K
# 78         JP1572FN2ZZ50K
# 79        WD-WCC3F5DAK3FN
# 79        WD-WCC3F5DAK3FN
# 79        WD-WCC3F5DAK3FN
# 79        WD-WCC3F5DAK3FN
# 79        WD-WCC3F5DAK3FN
# 80               S2WRY1ZL
# 80               S2WRY1ZL
# 81               W762TQ1D
# 81               W762TQ1D
# 81               W762TQ1D
# 81               W762TQ1D
# 81               W762TQ1D
# 81               W762TQ1D
# 82         S35ENA1K218696
# 83        WD-WXN0A99M8846
# 83        WD-WXN0A99M8846
# 84      MS89N67681050AI4C
# 84      MS89N67681050AI4C
# 85         S2YGJ9BDB00378
# 85         S2YGJ9BDB00378
# 85         S2YGJ9BDB00378
# 85         S2YGJ9BDB00378
# 86         S29NNXAH310493
# 87         S35ENX1J639355
# 88       50026B76832EE4C0
# 88       50026B76832EE4C0
# 89        WD-WCC6Z2PZJ5J6
# 89        WD-WCC6Z2PZJ5J6
# 89        WD-WCC6Z2PZJ5J6
# 89        WD-WCC6Z2PZJ5J6
# 90       50026B7779038D08
# 91         S443NX0M247605
# 92       CVLY628500ZW240D
# 92       CVLY628500ZW240D
# 92       CVLY628500ZW240D
# 92       CVLY628500ZW240D
# 93         S35ENA1K218765
# 94         S0NCNEAB204797
# 94         S0NCNEAB204797
# 95           172025800048
# 95           172025800048
# 95           172025800048
# 95           172025800048
# 96               6VPGKQSB
# 96               6VPGKQSB
# 96               6VPGKQSB
# 96               6VPGKQSB
# 97           1926BA803236
# 98           17OB604FKLGU
# 98           17OB604FKLGU
# 98           17OB604FKLGU
# 99       50026B724504B112
# 99       50026B724504B112
# 100  1512811100010247096D
# 100  1512811100010247096D
# 101       WD-WMC2E0H0THFZ
# 101       WD-WMC2E0H0THFZ
# 101       WD-WMC2E0H0THFZ
# 102     FJ84N78771180563N
# 103        S29PNXAGB08246
# 104          19518B807850
# 104          19518B807850
# 105        S29NNXAH334836
# 106       WD-WXP1A68K10T2
# 107        S29PNXAGB08240
# 108     MN92N06531180283C
# 108     MN92N06531180283C
# 109      50026B7777056B4E
# 109      50026B7777056B4E
# 109      50026B7777056B4E
# 109      50026B7777056B4E
# 110        TF0400Y13DUXWT
# 110        TF0400Y13DUXWT
# 110        TF0400Y13DUXWT
# 110        TF0400Y13DUXWT
# 110        TF0400Y13DUXWT
# 111       WD-WCC3FL06Z8UX
# 112     FJ84N787711805645
# 113          2J2920174536
# 113          2J2920174536
# 113          2J2920174536
# 113          2J2920174536
# 114          141597401579
# 114          141597401579
# 115        S4HENX0N914220
# 115        S4HENX0N914220
# 116      50026B723A07A700
# 117       WD-WCATRA646662
# 117       WD-WCATRA646662
# 117       WD-WCATRA646662
# 118        S4HENX0N915302
# 118        S4HENX0N915302
# 119        S364NX0J321843
# 120  TW00RNVG550853282794
# 120  TW00RNVG550853282794
# 120  TW00RNVG550853282794
# 120  TW00RNVG550853282794
# 120  TW00RNVG550853282794
# 120  TW00RNVG550853282794
# 120  TW00RNVG550853282794
# 121     AJ9BN87271020C34I
# 122       WD-WCC3F4RXXXYN
# 122       WD-WCC3F4RXXXYN
# 122       WD-WCC3F4RXXXYN
# 123          1915E1FABDE0
# 124          2I3220012770
# 124          2I3220012770
# 124          2I3220012770
# 124          2I3220012770
# 125        S364NX0JC11065
# 126          121439301694
# 127          142331405311
# 127          142331405311
# 128        S4HENX0N913956
# 128        S4HENX0N913956
# 129          14090C054E16
# 129          14090C054E16
# 129          14090C054E16
# 129          14090C054E16
# 129          14090C054E16
# 130        S509NF0N412106
# 131          1951AR446119
# 131          1951AR446119
# 132              5VPBT6WC
# 132              5VPBT6WC
# 132              5VPBT6WC
# 132              5VPBT6WC
# 133  100720PBPB04ECHXK99F
# 133  100720PBPB04ECHXK99F
# 133  100720PBPB04ECHXK99F
# 134              5VD7V8TD
# 134              5VD7V8TD
# 134              5VD7V8TD
# 135          1821E13F2047
# 135          1821E13F2047
# 135          1821E13F2047
# 136       WD-WX51A35453FU
# 136       WD-WX51A35453FU
# 136       WD-WX51A35453FU
# 137          2J2920178398
# 137          2J2920178398
# 137          2J2920178398
# 137          2J2920178398
# 138          2J2920175467
# 138          2J2920175467
# 138          2J2920175467
# 138          2J2920175467
# 139          2I4920063403
# 139          2I4920063403
# 139          2I4920063403
# 139          2I4920063403
# 140        S29NNXAH334897
# 141              6VMCTS4J
# 141              6VMCTS4J
# 141              6VMCTS4J
# 141              6VMCTS4J
# 142        S11DNYAD904713
# 142        S11DNYAD904713
# 143        S4HENX0N913672
# 143        S4HENX0N913672
# 144          1844E1D4C421
# 145        S35ENX1K626412
# 146        S364NA0J936948
# 147        S35ENA1K218828
# 148              Z4Y1K4TD
# 148              Z4Y1K4TD
# 148              Z4Y1K4TD
# 149     MJ8AN47581050A82F
# 150       WD-WCC3F6ZTZHT5
# 150       WD-WCC3F6ZTZHT5
# 150       WD-WCC3F6ZTZHT5
# 150       WD-WCC3F6ZTZHT5
# 151          174719C8763B
# 151          174719C8763B
# 152        S443NF0K628684
# 153        S35ENX1K116429
# 154            B828712403
# 154            B828712403
# 155        S35ENX0K421928
# 156        S35ENX1K710809
# 157        S50ANF0N648309
# 158          2048E4D3E55A
# 158          2048E4D3E55A
# 159        S35ENX1K666313
# 160  TW0XFJWX5508534J5943
# 160  TW0XFJWX5508534J5943
# 160  TW0XFJWX5508534J5943
# 161        S0NCNEAB300635
# 161        S0NCNEAB300635
# 161        S0NCNEAB300635
# 162        S35ENA1K218754
# 163          174020806082
# 163          174020806082
# 164        S3TNNF0K669924
# 165        S35ENX1K710677
# 166       WD-WCC2ENNAT5V2
# 166       WD-WCC2ENNAT5V2
# 166       WD-WCC2ENNAT5V2
# 167  TW0XVRV7LOH006CG00JW
# 168          174020802932
# 168          174020802932
# 168          174020802932
# 168          174020802932
# 169          18021A6C9650
# 169          18021A6C9650
# 170          171801803620
# 170          171801803620
# 170          171801803620
# 170          171801803620
# 171        S364NX0J321857
# 172       WD-WCC3F5DAKT6F
# 172       WD-WCC3F5DAKT6F
# 172       WD-WCC3F5DAKT6F
# 173       WD-WCC2EN8ZU22Z
# 173       WD-WCC2EN8ZU22Z
# 173       WD-WCC2EN8ZU22Z
# 174          2024E2AABA8C
# 174          2024E2AABA8C
# 175        S359NB0J446014
# 176        S35ENX0K421571
# 177          2J2920174500
# 177          2J2920174500
# 177          2J2920174500
# 177          2J2920174500
# 178          18021A88E733
# 178          18021A88E733
# 179              Z9AQP7ET
# 179              Z9AQP7ET
# 180          141597403493
# 180          141597403493
# 181     EJ85N40381CB9580D
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 182                   NaN
# 183        S35ENX0K422502
# 184             7491C8K3T
# 184             7491C8K3T
# 184             7491C8K3T
# 185          142366403382
# 185          142366403382
# 186          14090C054DA9
# 186          14090C054DA9
# 187        S35ENX0K756715
# 188          141597405056
# 188          141597405056
# 189        S364NX0J321897
# 190        S50ANF0N648261
# 191              Z6ECETW8
# 191              Z6ECETW8
# 192        S443NA0K945285
# 193       WD-WCC6Y4CVHUFT
# 193       WD-WCC6Y4CVHUFT
# 193       WD-WCC6Y4CVHUFT
# 193       WD-WCC6Y4CVHUFT
# 194     FJ64N503611404K4T
# 194     FJ64N503611404K4T
# 195       WD-WCC6Z2FS8KX3
# 195       WD-WCC6Z2FS8KX3
# 195       WD-WCC6Z2FS8KX3
# 196        S50ANF1N364088
# 197        S35ENX1K710666
# 198          141597404700
# 198          141597404700
# 198          141597404700
# 198          141597404700
# 199          171801804014
# 199          171801804014
# 199          171801804014
# 199          171801804014
# 200              S2WRMTGQ
# 200              S2WRMTGQ
# 200              S2WRMTGQ
# 200              S2WRMTGQ
# 201          192045801643
# 202     AJ9BN87271120C30K
# 203       WD-WMAV2FR98061
# 203       WD-WMAV2FR98061
# 203       WD-WMAV2FR98061
# 204          2J2920179059
# 204          2J2920179059
# 204          2J2920179059
# 204          2J2920179059
# 205          1849E1DC22B8
# 205          1849E1DC22B8
# 206     FJ84N787712605528
# 207          174719C8386B
# 207          174719C8386B
# 208  TW0V89JT5508567TB26N
# 208  TW0V89JT5508567TB26N
# 209        S35ENX0J108233
# 210       WD-WCC3F4TAE2E8
# 210       WD-WCC3F4TAE2E8
# 210       WD-WCC3F4TAE2E8
# 211        S35ENX0J637184
# 211        S35ENX0J637184
# 212       WD-WCC3F2SK3937
# 212       WD-WCC3F2SK3937
# 212       WD-WCC3F2SK3937
# 213        S35ENX1K710670
# 214        S364NX0JC11070
# 215              S2WPD4FM
# 215              S2WPD4FM
# 215              S2WPD4FM
# 215              S2WPD4FM
# 215              S2WPD4FM
# 216              W624Z98K
# 216              W624Z98K
# 216              W624Z98K
# 217        S364NX0J321832
# 218        S35ENX0K652023
# 219  TW0XFJWX5508534J5943
# 219  TW0XFJWX5508534J5943
# 219  TW0XFJWX5508534J5943
# 219  TW0XFJWX5508534J5943
# 220          1844E1D4C3F4
# 221  TW0XRV8D550854535272
# 221  TW0XRV8D550854535272
# 221  TW0XRV8D550854535272
# 221  TW0XRV8D550854535272
# 222          142367401579
# 222          142367401579
# 223     AN9AN60021110AV4N
# 224        S35ENX0K501640
# 225              5VD23JJK
# 225              5VD23JJK
# 225              5VD23JJK
# 226              S2WRMVCC
# 226              S2WRMVCC
# 226              S2WRMVCC
# 226              S2WRMVCC
# 227        S50ANF0NC09055
# 228      50026B777805D366
# 228      50026B777805D366
# 229        S50ANF0N647600
# 230          17OB6063KLGU
# 230          17OB6063KLGU
# 230          17OB6063KLGU
# 230          17OB6063KLGU
# 230          17OB6063KLGU
# 230          17OB6063KLGU
# 231        S35ENX0K334537
# 232        S35ENA1J993678
# 233       WD-WCC2EC7KAKYU
# 233       WD-WCC2EC7KAKYU
# 233       WD-WCC2EC7KAKYU
# 234  TW0V89JT5508567TB3QT
# 234  TW0V89JT5508567TB3QT
# 235        S443NE0M544126
# 235        S443NE0M544126
# 236              5RG1MG0G
# 236              5RG1MG0G
# 236              5RG1MG0G
# 236              5RG1MG0G
# 236              5RG1MG0G
# 237        S364NX0J321902
# 238             601BTEMFT
# 238             601BTEMFT
# 238             601BTEMFT
# 239          1851A8804499
# 240     ES84N731710204R2Q
# 241        S443NA0K945488
# 242       WD-WCC2EF7T8671
# 242       WD-WCC2EF7T8671
# 243       WD-WCC3F5DAKFZ8
# 243       WD-WCC3F5DAKFZ8
# 243       WD-WCC3F5DAKFZ8
# 244        S29NNXAGB29868
# 245        UKCVC01ZTEPEBW
# 245        UKCVC01ZTEPEBW
# 246       WD-WMC2E0N2SYJJ
# 246       WD-WMC2E0N2SYJJ
# 246       WD-WMC2E0N2SYJJ
# 247     AN9AN60021110AV4O
# 248  01D3075C0C3700159398
# 248  01D3075C0C3700159398
# 248  01D3075C0C3700159398
# 248  01D3075C0C3700159398
# 248  01D3075C0C3700159398
# 249          18021A6CC1B6
# 249          18021A6CC1B6
# 250             582KCAPST
# 250             582KCAPST
# 250             582KCAPST
# 250             582KCAPST
# 250             582KCAPST
# 250             582KCAPST
# 251        S50ANF1NC54429
# 252        S50ANF0N647647
# 253        S364NX0J321644
# 254        S364NX0JC05759
# 255        S359NB0J609878
# 256       WD-WCC3F7YCTS86
# 256       WD-WCC3F7YCTS86
# 256       WD-WCC3F7YCTS86
# 256       WD-WCC3F7YCTS86
# 257        S29NNXAH334901
# 258        S50ANF0N929676
# 259        S4HENX0N914182
# 259        S4HENX0N914182
# 260        S443NX0M247022
# 261          144307400495
# 261          144307400495
# 262              W620WK61
# 262              W620WK61
# 262              W620WK61
# 262              W620WK61
# 262              W620WK61
